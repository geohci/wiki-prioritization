# %% [markdown]
# # Newcomer Task Equity Analysis
# The goal of this analysis is to understand the impact of the Newcomer Tasks module -- i.e. a Wikimedia Foundation recommender system -- from the perspective of content equity. In particular, I examine the distribution of Wikipedia articles improved from the perspective of gender equity and geographic equity. In both cases, I ask the question whether the Newcomer Tasks system maintained the status quo (generally biases towards articles about men and the United States or language-relevant countries) or led to contributions to a more balanced distribution of articles.
#
# I look at Newcomer Tasks specifically for a few reasons:
# * It's relatively straightforward
# * It has good data -- i.e. both well-logged and sufficient usage to draw meaningful conclusions
# * And most importantly, it allows editors to select topics of interest to them so I can investigate how this self-selection affects content equity.
#
# NOTE: major thanks to Morten Warncke-Wang who provided indispensible guidance and example code -- e.g., https://github.com/wikimedia-research/2021-Growth-structured-tasks/blob/main/T277355-leading-indicators.ipynb

# %% [markdown]
# ## Setup

# %%
from collections import defaultdict
import os
import re

import pandas as pd

import wmfdata

# %%
spark = wmfdata.spark.get_session(app_name='pyspark regular; newcomereval',
                                  type='yarn-regular', # local, yarn-regular, yarn-large
                                  )
# Out:
# PySpark executors will use /usr/lib/anaconda-wmf/bin/python3.

# %% [markdown]
# ## Parameters

# %%
print("Mediawiki partitions:")
spark.sql("SHOW PARTITIONS wmf_raw.mediawiki_project_namespace_map").show(50, False)

print("\nWikidata partitions:")
spark.sql("SHOW PARTITIONS wmf.wikidata_item_page_link").show(50, False)
# Out:
# Mediawiki partitions:
# +------------------------+
# |partition               |
# +------------------------+
# |snapshot=2016-12_private|
# |snapshot=2017-07_private|
# |snapshot=2021-03        |
# |snapshot=2021-04        |
# |snapshot=2021-05        |
# |snapshot=2021-06        |
# |snapshot=2021-07        |
# |snapshot=2021-08        |
# +------------------------+
#
#
# Wikidata partitions:
# +-------------------+
# |partition          |
# +-------------------+
# |snapshot=2021-08-16|
# |snapshot=2021-08-23|
# |snapshot=2021-08-30|
# |snapshot=2021-09-06|
# |snapshot=2021-09-13|
# |snapshot=2021-09-20|
# +-------------------+

# %%
# Important parameters
mediawiki_snapshot = '2021-08'
wiki_dbs = ('viwiki','trwiki','ukwiki','svwiki','srwiki','ruwiki','ptwiki','kowiki','plwiki','hywiki','huwiki','hewiki','frwiki','fawiki','euwiki','cswiki','arwiki')
wikidata_snapshot = '2021-09-06'
newcomer_subset_tablename = 'isaacj.newcomer_tasks'
# bug where >20% of edits were missing (especially those accepted w/o bias) so to avoid the uncertainty and bias
# that that would insert into our results, we restrict to just stable (and mostly complete) Newcomer Tasks data
# https://github.com/nettrom/Growth-homepage-2019/blob/master/T266610_missing_tag_impact.ipynb
# start_date shouldn't be set to prior to '2020-10-28'
start_date = '2021-07-01'  # reduce amount of data so pipeline doesn't fail
known_users_tablename = 'known_users'
gen_table = 'isaacj.gender_wikidata'
geo_table = 'isaacj.qid_to_country_2021_08_02'

# %%
print("Gender data example:")
spark.sql(f'SELECT * FROM {gen_table} LIMIT 5').show(50, False)

print("\nGeography data example:")
spark.sql(f'SELECT * FROM {geo_table} LIMIT 5').show(50, False)
# Out:
# Gender data example:
# +----------+--------+
# |item_id   |gender  |
# +----------+--------+
# |Q100066   |Q6581072|
# |Q100137735|Q6581097|
# |Q100146397|Q6581097|
# |Q100152085|Q6581097|
# |Q100166821|Q6581097|
# +----------+--------+
#
#
# Geography data example:
# +---------+--------+-------+
# |qid      |property|country|
# +---------+--------+-------+
# |Q7068891 |P625    |Tuvalu |
# |Q34967204|P625    |Tuvalu |
# |Q11762732|P625    |Tuvalu |
# |Q15256609|P625    |Tuvalu |
# |Q3394461 |P625    |Tuvalu |
# +---------+--------+-------+

# %%
def qid_to_gender_category(qid):
    """Map individual Wikidata gender values to a few more categories so long-tail more likely to be represented."""
    # male, male organism, eunuch, cisgender male
    if qid in ('Q6581097', 'Q44148', 'Q179294', 'Q15145778'):
        return 'male'
    # female, female organism, cisgender female
    elif qid in ('Q6581072', 'Q43445', 'Q15145779'):
        return 'female'
    # transgender male, transmasculine
    elif qid in ('Q2449503', 'Q27679766'):
        return 'transgender male'
    # transgender female, transfeminine
    elif qid in ('Q1052281', 'Q27679684'):
        return 'transgender female'
    # contains identities like non-binary, transgender person, two-spirit, genderfluid, etc.
    # See for more details: https://www.wikidata.org/wiki/Property_talk:P21
    else:
        return 'non-binary'
    
spark.udf.register('gender_lbl', qid_to_gender_category, 'String')
# Out:
# <function __main__.qid_to_gender_category(qid)>

# %% [markdown]
# ### Gather Test Users
# Certain users are known to be test accounts and should be excluded. Most shouldn't show up anyways based on dates selected but better safe than sorry :)

# %%
## Lists of known users to ignore (e.g. test accounts and experienced users)
known_users = defaultdict(set)
known_users['cswiki'].update([14, 127629, 303170, 342147, 349875, 44133, 100304, 307410, 439792, 444907,
                              454862, 456272, 454003, 454846, 92295, 387915, 398470, 416764, 44751, 132801,
                              137787, 138342, 268033, 275298, 317739, 320225, 328302, 339583, 341191,
                              357559, 392634, 398626, 404765, 420805, 429109, 443890, 448195, 448438,
                              453220, 453628, 453645, 453662, 453663, 453664, 440694, 427497, 272273,
                              458025, 458487, 458049, 59563, 118067, 188859, 191908, 314640, 390445,
                              451069, 459434, 460802, 460885, 79895, 448735, 453176, 467557, 467745,
                              468502, 468583, 468603, 474052, 475184, 475185, 475187, 475188, 294174,
                              402906, 298011])

known_users['kowiki'].update([303170, 342147, 349875, 189097, 362732, 384066, 416362, 38759, 495265,
                              515553, 537326, 566963, 567409, 416360, 414929, 470932, 472019, 485036,
                              532123, 558423, 571587, 575553, 576758, 360703, 561281, 595100, 595105,
                              595610, 596025, 596651, 596652, 596653, 596654, 596655, 596993, 942,
                              13810, 536529])

known_users['viwiki'].update([451842, 628512, 628513, 680081, 680083, 680084, 680085, 680086, 355424,
                              387563, 443216, 682713, 659235, 700934, 705406, 707272, 707303, 707681, 585762])

known_users['arwiki'].update([237660, 272774, 775023, 1175449, 1186377, 1506091, 1515147, 1538902,
                              1568858, 1681813, 1683215, 1699418, 1699419, 1699425, 1740419, 1759328, 1763990])

## Grab the user IDs of known test accounts so they can be added to the exclusion list

def get_known_users(wiki):
    '''
    Get user IDs of known test accounts and return a set of them.
    '''
    
    username_patterns = ["MMiller", "Zilant", "Roan", "KHarlan", "MWang", "SBtest",
                         "Cloud", "Rho2019", "Test"]

    known_user_query = '''
    SELECT user_id
    FROM user
    WHERE user_name LIKE "{name_pattern}%"
    '''
    
    known_users = set()
    
    for u_pattern in username_patterns:
        new_known = wmfdata.mariadb.run(known_user_query.format(
            name_pattern = u_pattern), wiki)
        known_users = known_users | set(new_known['user_id'])

    return(known_users)
        
for wiki in wiki_dbs:
    known_users[wiki] = known_users[wiki] | get_known_users(wiki)
    print(wiki, len(known_users[wiki]))
# Out:
# viwiki 239
# trwiki 195
# ukwiki 182
# svwiki 264
# srwiki 70
# ruwiki 690
# ptwiki 553
# kowiki 361
# plwiki 339
# hywiki 27
# huwiki 102
# hewiki 241
# frwiki 1144
# fawiki 172
# euwiki 41
# cswiki 351
# arwiki 287

# %%
data = []
for wiki in known_users:
    for uid in known_users[wiki]:
        data.append((wiki, uid))
df = pd.DataFrame(data, columns=['wiki_db', 'user_id'])
spark.createDataFrame(df).createOrReplaceTempView(known_users_tablename)
spark.sql(f"SELECT * FROM {known_users_tablename} LIMIT 10").show(60, False)
# Out:
# +-------+-------+
# |wiki_db|user_id|
# +-------+-------+
# |cswiki |460802 |
# |cswiki |494595 |
# |cswiki |515077 |
# |cswiki |88069  |
# |cswiki |338952 |
# |cswiki |211978 |
# |cswiki |453643 |
# |cswiki |453644 |
# |cswiki |453645 |
# |cswiki |14     |
# +-------+-------+

# %% [markdown]
# ## Newcomer Edits
# Gather data on newcomer edits as identified by the `newcomer task` edit tag

# %%
create_table_query = f"""
    CREATE TABLE IF NOT EXISTS {newcomer_subset_tablename} (
        wiki_db                         STRING        COMMENT 'Wiki -- e.g., enwiki for English Wikipedia',
        page_id                         BIGINT        COMMENT 'Wikidata page ID',
        page_title                      STRING        COMMENT 'Page title (QID)',
        qid                             STRING        COMMENT 'Wikidata item ID',
        user_id                         BIGINT        COMMENT 'User ID; -1 if anonymous',
        user_text                       STRING        COMMENT 'User text; IP address if anonymous',
        revision_id                     BIGINT        COMMENT 'Revision ID',
        parent_rev_id                   BIGINT        COMMENT 'Parent revision ID',
        revision_timestamp              TIMESTAMP     COMMENT 'Revision timestamp (UTC)',
        revision_is_identity_reverted   BOOLEAN       COMMENT 'Was this revision reverted via identity revert?',
        gender                          STRING        COMMENT 'Gender value if exists and is human (as QID)',
        regions                         ARRAY<STRING> COMMENT 'List of regions associated with items'
    )
"""

print(create_table_query)
spark.sql(create_table_query)
# Out:
#     CREATE TABLE IF NOT EXISTS isaacj.newcomer_tasks (
#         wiki_db                         STRING        COMMENT 'Wiki -- e.g., enwiki for English Wikipedia',
#         page_id                         BIGINT        COMMENT 'Wikidata page ID',
#         page_title                      STRING        COMMENT 'Page title (QID)',
#         qid                             STRING        COMMENT 'Wikidata item ID',
#         user_id                         BIGINT        COMMENT 'User ID; -1 if anonymous',
#         user_text                       STRING        COMMENT 'User text; IP address if anonymous',
#         revision_id                     BIGINT        COMMENT 'Revision ID',
#         parent_rev_id                   BIGINT        COMMENT 'Parent revision ID',
#         revision_timestamp              TIMESTAMP     COMMENT 'Revision timestamp (UTC)',
#         revision_is_identity_reverted   BOOLEAN       COMMENT 'Was this revision reverted via identity revert?',
#         gender                          STRING        COMMENT 'Gender value if exists and is human (as QID)',
#         regions                         ARRAY<STRING> COMMENT 'List of regions associated with items'
#     )
# DataFrame[]

# %%
# Populate table with all edits made in these wikis that originated from Newcomer Tasks (excluding known test users)
#
# CTE explanations:
# * ne_edits: gather all newcomer task edits from mediawiki history snapshot (edit tag is always in English)
# * pid_to_qid: build map of wiki+page ID -> Wikidata ID for joining in equity components
# * regions: build map of Wikidata ID -> any associated regions (this data has been precomputed)
# * newcomer_edits_with_qid: join in Wikidata IDs to edit data and remove known test users from data
# * newcomer_edits_with_equity_facets: join in region + gender data
# * OVERWRITE: fill in time

print_for_hive = False
do_execute = True

query = f"""
WITH ne_edits AS (
  SELECT
    wiki_db,
    page_id,
    page_title,
    event_user_id AS user_id,
    REPLACE(event_user_text, ' ', '_') AS user_text,
    revision_id,
    revision_parent_id,
    CAST(event_timestamp AS TIMESTAMP) as revision_timestamp,
    revision_is_identity_reverted
  FROM wmf.mediawiki_history
  WHERE
    snapshot = '{mediawiki_snapshot}'
    AND wiki_db IN {wiki_dbs}
    AND page_namespace = 0
    AND NOT event_user_is_anonymous
    AND NOT SIZE(event_user_is_bot_by) > 0
    AND event_type = 'create'
    AND event_entity = 'revision'
    AND CAST(event_timestamp AS DATE) > '{start_date}'
    AND ARRAY_CONTAINS(revision_tags, 'newcomer task')
),
pid_to_qid AS (
    SELECT
      wiki_db,
      page_id,
      item_id
    FROM wmf.wikidata_item_page_link
    WHERE
      snapshot = '{wikidata_snapshot}'
      AND wiki_db in {wiki_dbs}
      AND page_namespace = 0
),
regions AS (
  SELECT
    qid AS qid,
    COLLECT_SET(country) AS regions
  FROM {geo_table} g
  INNER JOIN pid_to_qid p
    ON (g.qid = p.item_id)
  GROUP BY
    qid
),
newcomer_edits_with_qid AS (
  SELECT
    ne.*,
    pq.item_id AS qid
  FROM ne_edits ne
  LEFT ANTI JOIN {known_users_tablename} ku
    ON (ne.wiki_db = ku.wiki_db
        AND ne.user_id = ku.user_id)
  LEFT JOIN pid_to_qid pq
    ON (ne.wiki_db = pq.wiki_db
        AND ne.page_id = pq.page_id)
),
newcomer_edits_with_equity_facets AS (
  SELECT
    ne.*,
    g.gender AS gender,
    r.regions AS regions
  FROM newcomer_edits_with_qid ne
  LEFT JOIN {gen_table} g
    ON (ne.qid = g.item_id)
  LEFT JOIN regions r
    ON (ne.qid = r.qid)
)
INSERT OVERWRITE TABLE {newcomer_subset_tablename}
  SELECT
    wiki_db,
    page_id,
    page_title,
    qid,
    user_id,
    user_text,
    revision_id,
    revision_parent_id,
    revision_timestamp,
    revision_is_identity_reverted,
    gender,
    regions
  FROM newcomer_edits_with_equity_facets
"""

if print_for_hive:
    print(re.sub(' +', ' ', re.sub('\n', ' ', query)).strip())
else:
    print(query)

if do_execute:
    result = spark.sql(query)
# Out:
# WITH ne_edits AS (
#   SELECT
#     wiki_db,
#     page_id,
#     page_title,
#     event_user_id AS user_id,
#     REPLACE(event_user_text, ' ', '_') AS user_text,
#     revision_id,
#     revision_parent_id,
#     CAST(event_timestamp AS TIMESTAMP) as revision_timestamp,
#     revision_is_identity_reverted
#   FROM wmf.mediawiki_history
#   WHERE
#     snapshot = '2021-08'
#     AND wiki_db IN ('viwiki', 'trwiki', 'ukwiki', 'svwiki', 'srwiki', 'ruwiki', 'ptwiki', 'kowiki', 'plwiki', 'hywiki', 'huwiki', 'hewiki', 'frwiki', 'fawiki', 'euwiki', 'cswiki', 'arwiki')
#     AND page_namespace = 0
#     AND NOT event_user_is_anonymous
#     AND NOT SIZE(event_user_is_bot_by) > 0
#     AND event_type = 'create'
#     AND event_entity = 'revision'
#     AND CAST(event_timestamp AS DATE) > '2021-07-01'
#     AND ARRAY_CONTAINS(revision_tags, 'newcomer task')
# ),
# pid_to_qid AS (
#     SELECT
#       wiki_db,
#       page_id,
#       item_id
#     FROM wmf.wikidata_item_page_link
#     WHERE
#       snapshot = '2021-09-06'
#       AND wiki_db in ('viwiki', 'trwiki', 'ukwiki', 'svwiki', 'srwiki', 'ruwiki', 'ptwiki', 'kowiki', 'plwiki', 'hywiki', 'huwiki', 'hewiki', 'frwiki', 'fawiki', 'euwiki', 'cswiki', 'arwiki')
#       AND page_namespace = 0
# ),
# regions AS (
#   SELECT
#     qid AS qid,
#     COLLECT_SET(country) AS regions
#   FROM isaacj.qid_to_country_2021_08_02 g
#   INNER JOIN pid_to_qid p
#     ON (g.qid = p.item_id)
#   GROUP BY
#     qid
# ),
# newcomer_edits_with_qid AS (
#   SELECT
#     ne.*,
#     pq.item_id AS qid
#   FROM ne_edits ne
#   LEFT ANTI JOIN known_users ku
#     ON (ne.wiki_db = ku.wiki_db
#         AND ne.user_id = ku.user_id)
#   LEFT JOIN pid_to_qid pq
#     ON (ne.wiki_db = pq.wiki_db
#         AND ne.page_id = pq.page_id)
# ),
# newcomer_edits_with_equity_facets AS (
#   SELECT
#     ne.*,
#     g.gender AS gender,
#     r.regions AS regions
#   FROM newcomer_edits_with_qid ne
#   LEFT JOIN isaacj.gender_wikidata g
#     ON (ne.qid = g.item_id)
#   LEFT JOIN regions r
#     ON (ne.qid = r.qid)
# )
# INSERT OVERWRITE TABLE isaacj.newcomer_tasks
#   SELECT
#     wiki_db,
#     page_id,
#     page_title,
#     qid,
#     user_id,
#     user_text,
#     revision_id,
#     revision_parent_id,
#     revision_timestamp,
#     revision_is_identity_reverted,
#     gender,
#     regions
#   FROM newcomer_edits_with_equity_facets

# %% [markdown]
# ### Descriptive stats

# %%
# basic summary stats for edits for all wikis
# NOTE: num_rows should equal num_edits but occasionally a row is duplicated when joining in gender info
print_for_hive = False
do_execute = True

query = f"""
SELECT
  wiki_db,
  COUNT(1) AS num_rows,
  COUNT(DISTINCT(revision_id)) AS num_edits,
  COUNT(DISTINCT(page_id)) AS num_pages,
  COUNT(DISTINCT(user_id)) AS num_users,
  SUM(IF(gender IS NOT NULL, 1, 0)) AS edits_to_bios,
  SUM(IF(regions IS NOT NULL, 1, 0)) AS edits_to_geos,
  SUM(IF(revision_is_identity_reverted, 1, 0)) / COUNT(DISTINCT(revision_id)) AS pct_reverted
FROM {newcomer_subset_tablename}
GROUP BY
  wiki_db
ORDER BY
  num_edits DESC
"""

if print_for_hive:
    print(re.sub(' +', ' ', re.sub('\n', ' ', query)).strip())
else:
    print(query)

if do_execute:
    spark.sql(query).show(50, False)
# Out:
# SELECT
#   wiki_db,
#   COUNT(1) AS num_rows,
#   COUNT(DISTINCT(revision_id)) AS num_edits,
#   COUNT(DISTINCT(page_id)) AS num_pages,
#   COUNT(DISTINCT(user_id)) AS num_users,
#   SUM(IF(gender IS NOT NULL, 1, 0)) AS edits_to_bios,
#   SUM(IF(regions IS NOT NULL, 1, 0)) AS edits_to_geos,
#   SUM(IF(revision_is_identity_reverted, 1, 0)) / COUNT(DISTINCT(revision_id)) AS pct_reverted
# FROM isaacj.newcomer_tasks
# GROUP BY
#   wiki_db
# ORDER BY
#   num_edits DESC
#
# +-------+--------+---------+---------+---------+-------------+-------------+--------------------+
# |wiki_db|num_rows|num_edits|num_pages|num_users|edits_to_bios|edits_to_geos|pct_reverted        |
# +-------+--------+---------+---------+---------+-------------+-------------+--------------------+
# |fawiki |5763    |5763     |4908     |617      |1039         |2775         |0.06819364914107236 |
# |ruwiki |4667    |4666     |3491     |747      |1190         |2580         |0.04414916416630947 |
# |frwiki |3752    |3751     |3388     |545      |1066         |2099         |0.024526792855238604|
# |arwiki |3206    |3206     |2979     |593      |755          |1509         |0.10511540860885839 |
# |viwiki |2133    |2133     |1997     |204      |313          |798          |0.04125644631973746 |
# |plwiki |1817    |1817     |1718     |156      |537          |1025         |0.05228398458998349 |
# |ptwiki |1788    |1788     |1127     |402      |417          |1077         |0.10570469798657718 |
# |huwiki |1662    |1662     |1642     |56       |303          |884          |0.06377858002406739 |
# |ukwiki |1115    |1115     |438      |96       |328          |479          |0.025112107623318385|
# |cswiki |736     |736      |719      |86       |184          |366          |0.03125             |
# |trwiki |623     |623      |454      |196      |99           |269          |0.15730337078651685 |
# |kowiki |550     |550      |392      |79       |133          |250          |0.05090909090909091 |
# |hewiki |475     |475      |302      |141      |107          |246          |0.09052631578947369 |
# |svwiki |173     |173      |124      |44       |34           |118          |0.05202312138728324 |
# |srwiki |52      |52       |37       |21       |12           |33           |0.19230769230769232 |
# |hywiki |47      |47       |29       |14       |1            |11           |0.0                 |
# |euwiki |15      |15       |13       |4        |3            |9            |0.0                 |
# +-------+--------+---------+---------+---------+-------------+-------------+--------------------+

# %% [markdown]
# ## Newcomer Clicks + Impressions
# This data fills out the newcomer task funnel (impression -> click -> edit) and also allows us to inspect the impact of topic filtering. It is spread out across three tables:
# * https://meta.wikimedia.org/wiki/Schema:NewcomerTask (`event.newcomertask`)
# * https://meta.wikimedia.org/wiki/Schema:HelpPanel (`event.helppanel`)
# * https://meta.wikimedia.org/wiki/Schema:HomepageModule (`event.homepagemodule`)

# %%
# Important parameters
events_subset_tablename = 'isaacj.newcomer_tasks_events'
# dates to match what was extracted from edit data
start_year = 2021
start_month = 7
start_day = 1
end_year = 2021
end_month = 9
end_day = 5
# these tables are updated in separate scripts but largely are extraction of data from Wikidata
gen_table = 'isaacj.gender_wikidata'
geo_table = 'isaacj.qid_to_country_2021_08_02'

# %%
create_table_query = f"""
    CREATE TABLE IF NOT EXISTS {events_subset_tablename} (
        wiki_db                         STRING        COMMENT 'Wiki -- e.g., enwiki for English Wikipedia',
        page_id                         BIGINT        COMMENT 'Wikidata page ID',
        page_title                      STRING        COMMENT 'Page title (QID)',
        parent_rev_id                   BIGINT        COMMENT 'Revision ID of article (when seen/clicked)',
        qid                             STRING        COMMENT 'Wikidata item ID',
        user_id                         BIGINT        COMMENT 'User ID',
        interaction_type                STRING        COMMENT 'impression or click',
        task_type                       STRING        COMMENT 'Type of structured task -- e.g., add-a-link',
        task_topic                      STRING        COMMENT 'Most relevant user-selected topic to recommendation',
        gender                          STRING        COMMENT 'Gender value if exists and is human (as QID)',
        regions                         ARRAY<STRING> COMMENT 'List of regions associated with items',
        year                            INT           COMMENT 'year',
        month                           INT           COMMENT 'month',
        day                             INT           COMMENT 'day'
    )
"""

print(create_table_query)
spark.sql(create_table_query)
# Out:
#     CREATE TABLE IF NOT EXISTS isaacj.newcomer_tasks_events (
#         wiki_db                         STRING        COMMENT 'Wiki -- e.g., enwiki for English Wikipedia',
#         page_id                         BIGINT        COMMENT 'Wikidata page ID',
#         page_title                      STRING        COMMENT 'Page title (QID)',
#         parent_rev_id                   BIGINT        COMMENT 'Revision ID of article (when seen/clicked)',
#         qid                             STRING        COMMENT 'Wikidata item ID',
#         user_id                         BIGINT        COMMENT 'User ID',
#         interaction_type                STRING        COMMENT 'impression or click',
#         task_type                       STRING        COMMENT 'Type of structured task -- e.g., add-a-link',
#         task_topic                      STRING        COMMENT 'Most relevant user-selected topic to recommendation',
#         gender                          STRING        COMMENT 'Gender value if exists and is human (as QID)',
#         regions                         ARRAY<STRING> COMMENT 'List of regions associated with items',
#         year                            INT           COMMENT 'year',
#         month                           INT           COMMENT 'month',
#         day                             INT           COMMENT 'day'
#     )
# DataFrame[]

# %%
# Populate table with EventLogging data on impressions + clicks to recommendation cards.
#
# Explanation of CTEs:
# * newcomer_page_info: gather info on articles+topics with cards that were seen/clicked on. Distinct because I don't really care about duplicate clicks and it can be very noisy.
# * newcomer_action_info: gather info on users that interacted (saw/clicked) with newcomer task cards. This is split across the homepagemodule (homepage module) and helppanel (post-edit module) eventlogging. Distinct because I don't really care about duplicate views and it can be very noisy.
#   * NOTE: the different tables will have different interaction_types but functionally we can treat anything %impression as an impression and %click as a click.
# * newcomer_info: join page info with user info for complete data
# * newcomers_without_known_users: remove known users
# * pid_to_qid: get mapping of article page IDs -> Wikidata IDs to join in equity components
# * regions: gather relevant geographic info
# * newcomer_info_with_qid: add Wikidata IDs to impression/click data
# * newcomer_info_with_equity_facets: join in gender/geographic info
# * INSERT: load into table for further processing

print_for_hive = False
do_execute = True

query = f"""
WITH newcomer_page_info AS (
    SELECT DISTINCT
      event.newcomer_task_token AS newcomer_task_token,
      wiki as wiki_db,
      event.page_id AS page_id,
      event.page_title AS page_title,
      event.revision_id AS parent_rev_id,
      event.task_type AS task_type,
      COALESCE(event.topic, 'no-topic') AS task_topic,
      year,
      month,
      day
    FROM event.newcomertask
    WHERE
      (year = {start_year} AND ((month > {start_month} OR (month = {start_month} and day >= {start_day}))))
      AND (year = {end_year} AND ((month < {end_month} OR (month = {end_month} and day <= {end_day}))))
      AND wiki in {wiki_dbs}
),
newcomer_action_info AS (
    SELECT DISTINCT
      newcomer_task_token,
      user_id,
      interaction_type
    FROM
    (
        SELECT
          str_to_map(event.action_data, ';', '=')['newcomerTaskToken'] AS newcomer_task_token,
          event.user_id AS user_id,
          event.action AS interaction_type
        FROM event.homepagemodule
        WHERE
          (year = {start_year} AND ((month > {start_month} OR (month = {start_month} and day >= {start_day}))))
          AND (year = {end_year} AND ((month < {end_month} OR (month = {end_month} and day <= {end_day}))))
          AND wiki in {wiki_dbs}
          AND (event.action = 'se-task-click' OR event.action = 'se-task-impression')
        UNION ALL
        SELECT
          str_to_map(event.action_data, ';', '=')['newcomerTaskToken'] AS newcomer_task_token,
          event.user_id AS user_id,
          event.action AS interaction_type
        FROM event.helppanel
        WHERE
          (year = {start_year} AND ((month > {start_month} OR (month = {start_month} and day >= {start_day}))))
          AND (year = {end_year} AND ((month < {end_month} OR (month = {end_month} and day <= {end_day}))))
          AND wiki in {wiki_dbs}
          AND (event.action = 'postedit-task-click' OR event.action = 'postedit-impression')
    ) a
    WHERE
      newcomer_task_token IS NOT NULL
),
newcomer_info AS (
    SELECT
      wiki_db,
      page_id,
      page_title,
      parent_rev_id,
      user_id,
      interaction_type,
      task_type,
      task_topic,
      year,
      month,
      day
    FROM newcomer_page_info npi
    INNER JOIN newcomer_action_info nai
      ON (npi.newcomer_task_token = nai.newcomer_task_token)
),
newcomers_without_known_users AS (
    SELECT
      *
    FROM newcomer_info ni
    LEFT ANTI JOIN known_users ku
    ON (ni.wiki_db = ku.wiki_db
        AND ni.user_id = ku.user_id)
),
pid_to_qid AS (
    SELECT
      wiki_db,
      page_id,
      item_id
    FROM wmf.wikidata_item_page_link
    WHERE
      snapshot = '{wikidata_snapshot}'
      AND wiki_db in {wiki_dbs}
      AND page_namespace = 0
),
regions AS (
  SELECT
    qid AS qid,
    COLLECT_SET(country) AS regions
  FROM {geo_table} g
  INNER JOIN pid_to_qid p
    ON (g.qid = p.item_id)
  GROUP BY
    qid
),
newcomer_info_with_qid AS (
  SELECT
    ni.*,
    pq.item_id AS qid
  FROM newcomer_info ni
  LEFT JOIN pid_to_qid pq
    ON (ni.wiki_db = pq.wiki_db
        AND ni.page_id = pq.page_id)
),
newcomer_info_with_equity_facets AS (
  SELECT
    ni.*,
    g.gender AS gender,
    r.regions AS regions
  FROM newcomer_info_with_qid ni
  LEFT JOIN {gen_table} g
    ON (ni.qid = g.item_id)
  LEFT JOIN regions r
    ON (ni.qid = r.qid)
)
INSERT OVERWRITE TABLE {events_subset_tablename}
  SELECT
    wiki_db,
    page_id,
    page_title,
    parent_rev_id,
    qid,
    user_id,
    interaction_type,
    task_type,
    task_topic,
    gender,
    regions,
    year,
    month,
    day
  FROM newcomer_info_with_equity_facets
"""

if print_for_hive:
    print(re.sub(' +', ' ', re.sub('\n', ' ', query)).strip())
else:
    print(query)

if do_execute:
    result = spark.sql(query)
# Out:
# WITH newcomer_page_info AS (
#     SELECT DISTINCT
#       event.newcomer_task_token AS newcomer_task_token,
#       wiki as wiki_db,
#       event.page_id AS page_id,
#       event.page_title AS page_title,
#       event.revision_id AS parent_rev_id,
#       event.task_type AS task_type,
#       COALESCE(event.topic, 'no-topic') AS task_topic,
#       year,
#       month,
#       day
#     FROM event.newcomertask
#     WHERE
#       (year = 2021 AND ((month > 7 OR (month = 7 and day >= 1))))
#       AND (year = 2021 AND ((month < 9 OR (month = 9 and day <= 5))))
#       AND wiki in ('viwiki', 'trwiki', 'ukwiki', 'svwiki', 'srwiki', 'ruwiki', 'ptwiki', 'kowiki', 'plwiki', 'hywiki', 'huwiki', 'hewiki', 'frwiki', 'fawiki', 'euwiki', 'cswiki', 'arwiki')
# ),
# newcomer_action_info AS (
#     SELECT DISTINCT
#       newcomer_task_token,
#       user_id,
#       interaction_type
#     FROM
#     (
#         SELECT
#           str_to_map(event.action_data, ';', '=')['newcomerTaskToken'] AS newcomer_task_token,
#           event.user_id AS user_id,
#           event.action AS interaction_type
#         FROM event.homepagemodule
#         WHERE
#           (year = 2021 AND ((month > 7 OR (month = 7 and day >= 1))))
#           AND (year = 2021 AND ((month < 9 OR (month = 9 and day <= 5))))
#           AND wiki in ('viwiki', 'trwiki', 'ukwiki', 'svwiki', 'srwiki', 'ruwiki', 'ptwiki', 'kowiki', 'plwiki', 'hywiki', 'huwiki', 'hewiki', 'frwiki', 'fawiki', 'euwiki', 'cswiki', 'arwiki')
#           AND (event.action = 'se-task-click' OR event.action = 'se-task-impression')
#         UNION ALL
#         SELECT
#           str_to_map(event.action_data, ';', '=')['newcomerTaskToken'] AS newcomer_task_token,
#           event.user_id AS user_id,
#           event.action AS interaction_type
#         FROM event.helppanel
#         WHERE
#           (year = 2021 AND ((month > 7 OR (month = 7 and day >= 1))))
#           AND (year = 2021 AND ((month < 9 OR (month = 9 and day <= 5))))
#           AND wiki in ('viwiki', 'trwiki', 'ukwiki', 'svwiki', 'srwiki', 'ruwiki', 'ptwiki', 'kowiki', 'plwiki', 'hywiki', 'huwiki', 'hewiki', 'frwiki', 'fawiki', 'euwiki', 'cswiki', 'arwiki')
#           AND (event.action = 'postedit-task-click' OR event.action = 'postedit-impression')
#     ) a
#     WHERE
#       newcomer_task_token IS NOT NULL
# ),
# newcomer_info AS (
#     SELECT
#       wiki_db,
#       page_id,
#       page_title,
#       parent_rev_id,
#       user_id,
#       interaction_type,
#       task_type,
#       task_topic,
#       year,
#       month,
#       day
#     FROM newcomer_page_info npi
#     INNER JOIN newcomer_action_info nai
#       ON (npi.newcomer_task_token = nai.newcomer_task_token)
# ),
# newcomers_without_known_users AS (
#     SELECT
#       *
#     FROM newcomer_info ni
#     LEFT ANTI JOIN known_users ku
#     ON (ni.wiki_db = ku.wiki_db
#         AND ni.user_id = ku.user_id)
# ),
# pid_to_qid AS (
#     SELECT
#       wiki_db,
#       page_id,
#       item_id
#     FROM wmf.wikidata_item_page_link
#     WHERE
#       snapshot = '2021-09-06'
#       AND wiki_db in ('viwiki', 'trwiki', 'ukwiki', 'svwiki', 'srwiki', 'ruwiki', 'ptwiki', 'kowiki', 'plwiki', 'hywiki', 'huwiki', 'hewiki', 'frwiki', 'fawiki', 'euwiki', 'cswiki', 'arwiki')
#       AND page_namespace = 0
# ),
# regions AS (
#   SELECT
#     qid AS qid,
#     COLLECT_SET(country) AS regions
#   FROM isaacj.qid_to_country_2021_08_02 g
#   INNER JOIN pid_to_qid p
#     ON (g.qid = p.item_id)
#   GROUP BY
#     qid
# ),
# newcomer_info_with_qid AS (
#   SELECT
#     ni.*,
#     pq.item_id AS qid
#   FROM newcomer_info ni
#   LEFT JOIN pid_to_qid pq
#     ON (ni.wiki_db = pq.wiki_db
#         AND ni.page_id = pq.page_id)
# ),
# newcomer_info_with_equity_facets AS (
#   SELECT
#     ni.*,
#     g.gender AS gender,
#     r.regions AS regions
#   FROM newcomer_info_with_qid ni
#   LEFT JOIN isaacj.gender_wikidata g
#     ON (ni.qid = g.item_id)
#   LEFT JOIN regions r
#     ON (ni.qid = r.qid)
# )
# INSERT OVERWRITE TABLE isaacj.newcomer_tasks_events
#   SELECT
#     wiki_db,
#     page_id,
#     page_title,
#     parent_rev_id,
#     qid,
#     user_id,
#     interaction_type,
#     task_type,
#     task_topic,
#     gender,
#     regions,
#     year,
#     month,
#     day
#   FROM newcomer_info_with_equity_facets

# %% [markdown]
# ### Descriptive stats

# %%
# basic summary stats for all wikis
print_for_hive = False
do_execute = True

query = f"""
SELECT
  wiki_db,
  interaction_type,
  COUNT(1) AS num_rows,
  COUNT(DISTINCT(user_id)) AS num_users,
  COUNT(DISTINCT(page_id)) AS num_pages,
  SUM(IF(gender IS NOT NULL, 1, 0)) AS events_to_bios,
  SUM(IF(regions IS NOT NULL, 1, 0)) AS events_to_geos,
  SUM(IF(task_topic ='no-topic', 0, 1)) AS events_with_topics
FROM {events_subset_tablename}
GROUP BY
  wiki_db,
  interaction_type
ORDER BY
  wiki_db,
  interaction_type
"""

if print_for_hive:
    print(re.sub(' +', ' ', re.sub('\n', ' ', query)).strip())
else:
    print(query)

if do_execute:
    spark.sql(query).show(100, False)
# Out:
# SELECT
#   wiki_db,
#   interaction_type,
#   COUNT(1) AS num_rows,
#   COUNT(DISTINCT(user_id)) AS num_users,
#   COUNT(DISTINCT(page_id)) AS num_pages,
#   SUM(IF(gender IS NOT NULL, 1, 0)) AS events_to_bios,
#   SUM(IF(regions IS NOT NULL, 1, 0)) AS events_to_geos,
#   SUM(IF(task_topic ='no-topic', 0, 1)) AS events_with_topics
# FROM isaacj.newcomer_tasks_events
# GROUP BY
#   wiki_db,
#   interaction_type
# ORDER BY
#   wiki_db,
#   interaction_type
#
# +-------+-------------------+--------+---------+---------+--------------+--------------+------------------+
# |wiki_db|interaction_type   |num_rows|num_users|num_pages|events_to_bios|events_to_geos|events_with_topics|
# +-------+-------------------+--------+---------+---------+--------------+--------------+------------------+
# |arwiki |postedit-impression|3888    |629      |3596     |1074          |2088          |2999              |
# |arwiki |postedit-task-click|1711    |203      |1643     |506           |918           |1418              |
# |arwiki |se-task-click      |4228    |1631     |3769     |1039          |2042          |1637              |
# |arwiki |se-task-impression |80989   |6082     |36203    |22062         |41790         |32476             |
# |cswiki |postedit-impression|786     |82       |715      |184           |362           |525               |
# |cswiki |postedit-task-click|501     |30       |478      |127           |243           |336               |
# |cswiki |se-task-click      |1260    |182      |1178     |277           |600           |490               |
# |cswiki |se-task-impression |19792   |656      |10922    |4652          |10059         |8429              |
# |euwiki |postedit-impression|15      |4        |15       |4             |4             |13                |
# |euwiki |postedit-task-click|1       |1        |1        |0             |0             |1                 |
# |euwiki |se-task-click      |48      |6        |46       |6             |18            |41                |
# |euwiki |se-task-impression |841     |25       |472      |138           |325           |643               |
# |fawiki |postedit-impression|6091    |627      |5101     |1280          |3095          |4459              |
# |fawiki |postedit-task-click|3649    |267      |3358     |746           |1921          |2693              |
# |fawiki |se-task-click      |4252    |1206     |3125     |867           |1921          |1749              |
# |fawiki |se-task-impression |83478   |4466     |22496    |19927         |39747         |40583             |
# |frwiki |postedit-impression|3972    |517      |3620     |1261          |2295          |3245              |
# |frwiki |postedit-task-click|1763    |198      |1736     |510           |1040          |1457              |
# |frwiki |se-task-click      |3853    |1331     |3299     |1151          |2185          |1856              |
# |frwiki |se-task-impression |79439   |5122     |31255    |25691         |48018         |40195             |
# |hewiki |postedit-impression|353     |126      |331      |98            |178           |311               |
# |hewiki |postedit-task-click|50      |33       |50       |11            |23            |40                |
# |hewiki |se-task-click      |932     |296      |806      |220           |490           |570               |
# |hewiki |se-task-impression |27728   |908      |8384     |8203          |14930         |16996             |
# |huwiki |postedit-impression|4555    |57       |3699     |1052          |2383          |4263              |
# |huwiki |postedit-task-click|1460    |25       |1446     |260           |801           |1342              |
# |huwiki |se-task-click      |590     |124      |569      |117           |306           |404               |
# |huwiki |se-task-impression |12116   |407      |7224     |3060          |6944          |8079              |
# |hywiki |postedit-impression|48      |13       |41       |3             |14            |31                |
# |hywiki |postedit-task-click|4       |4        |4        |1             |2             |2                 |
# |hywiki |se-task-click      |119     |40       |90       |8             |35            |77                |
# |hywiki |se-task-impression |4605    |147      |1325     |264           |1100          |1903              |
# |kowiki |postedit-impression|514     |74       |456      |110           |249           |484               |
# |kowiki |postedit-task-click|243     |36       |229      |53            |117           |228               |
# |kowiki |se-task-click      |682     |191      |576      |97            |292           |357               |
# |kowiki |se-task-impression |19090   |586      |6055     |3619          |8279          |9676              |
# |plwiki |postedit-impression|1816    |156      |1596     |516           |993           |1723              |
# |plwiki |postedit-task-click|920     |64       |909      |281           |507           |892               |
# |plwiki |se-task-click      |1958    |305      |1289     |371           |1055          |807               |
# |plwiki |se-task-impression |39304   |1086     |13947    |9380          |22638         |25271             |
# |ptwiki |postedit-impression|1457    |352      |1238     |369           |889           |1176              |
# |ptwiki |postedit-task-click|267     |111      |255      |58            |148           |217               |
# |ptwiki |se-task-click      |2830    |1247     |1997     |642           |1699          |1427              |
# |ptwiki |se-task-impression |72845   |5341     |14663    |18146         |43843         |34543             |
# |ruwiki |postedit-impression|4740    |729      |3704     |1170          |2674          |3627              |
# |ruwiki |postedit-task-click|1842    |297      |1724     |430           |1094          |1523              |
# |ruwiki |se-task-click      |5340    |1423     |3171     |1258          |2744          |2791              |
# |ruwiki |se-task-impression |107095  |4852     |23392    |27921         |55744         |55672             |
# |srwiki |postedit-impression|41      |20       |41       |15            |16            |24                |
# |srwiki |postedit-task-click|5       |5        |5        |3             |2             |3                 |
# |srwiki |se-task-click      |99      |56       |94       |27            |47            |43                |
# |srwiki |se-task-impression |4291    |171      |2049     |1410          |1863          |1346              |
# |svwiki |postedit-impression|140     |41       |114      |35            |88            |110               |
# |svwiki |postedit-task-click|45      |17       |44       |10            |28            |39                |
# |svwiki |se-task-click      |311     |106      |207      |71            |188           |168               |
# |svwiki |se-task-impression |7034    |427      |1433     |1852          |4289          |4034              |
# |trwiki |postedit-impression|506     |171      |437      |113           |232           |419               |
# |trwiki |postedit-task-click|122     |60       |117      |26            |51            |98                |
# |trwiki |se-task-click      |1453    |609      |996      |261           |611           |863               |
# |trwiki |se-task-impression |42339   |2126     |6236     |10351         |20712         |24512             |
# |ukwiki |postedit-impression|950     |87       |678      |273           |416           |604               |
# |ukwiki |postedit-task-click|104     |34       |103      |29            |43            |56                |
# |ukwiki |se-task-click      |776     |165      |640      |201           |349           |368               |
# |ukwiki |se-task-impression |16722   |595      |4558     |4998          |8154          |8802              |
# |viwiki |postedit-impression|2465    |217      |2211     |458           |1083          |1689              |
# |viwiki |postedit-task-click|1137    |63       |1109     |212           |508           |664               |
# |viwiki |se-task-click      |2212    |488      |1978     |306           |803           |1075              |
# |viwiki |se-task-impression |36303   |1541     |16177    |6519          |15824         |17737             |
# +-------+-------------------+--------+---------+---------+--------------+--------------+------------------+

# %% [markdown]
# ## Analysis

# %%
# NOTE: this is >1000 pages edited (above) and no major power users (data from ad-hoc analyses section)
wikis_with_stable_data = ['fawiki', 'ruwiki', 'frwiki', 'arwiki']

# Some of the data on power contributors used to make above determination
"""
+----------------+-------+-------+----------+--------------------+
|interaction_type|wiki_db|user_id|num_events|pct_events          |
+----------------+-------+-------+----------+--------------------+
|1-impression    |euwiki |< del >|542       |0.633177570093458   |
|1-impression    |huwiki |< del >|5933      |0.3558874692579929  |
|1-impression    |srwiki |< del >|1145      |0.2643120960295475  |
|3-edit          |cswiki |< del >|80        |0.10869565217391304 |
|3-edit          |svwiki |< del >|18        |0.10404624277456648 |
|3-edit          |ukwiki |< del >|114       |0.10224215246636771 |
+----------------+-------+-------+----------+--------------------+
"""
print(wikis_with_stable_data)
# Out:
# ['fawiki', 'ruwiki', 'frwiki', 'arwiki']

# %%
# gender equity for edits by language
#
# CTEs:
# * qids: gather all QIDs with a Wikipedia article in a given language
# * baseline: get baseline gender distribution for the language by joining qids with gender data (articles without gender ignored)
# * baseline_pct: convert counts into percentages
# * ne_edits: get edit data stratified by gender from newcomer tasks
# * SELECT: join together edit gender data and baseline gender data (some filtering to reduce size of output)
# 
# NOTE: baseline is generally ~80% male, ~20% female, ~1% non-binary / transgender but does vary a bit by wiki

print_for_hive = False
do_execute = True

for wikidb in wikis_with_stable_data:
    print(f"\n== Analyzing {wikidb} ==")
    query = f"""
    with qids AS (
        SELECT
          item_id
        FROM wmf.wikidata_item_page_link
        WHERE
          snapshot = '{wikidata_snapshot}'
          AND wiki_db = '{wikidb}'
          AND page_namespace = 0
    ),
    baseline AS (
        SELECT
          gender_lbl(gender) AS gender_cat,
          COUNT(1) AS num_bios
        FROM {gen_table} g
        INNER JOIN qids q
          ON (g.item_id = q.item_id)
        WHERE
          gender IS NOT NULL
        GROUP BY
          gender_cat
    ),
    baseline_pct AS (
        SELECT
          gender_cat,
          num_bios / (SUM(num_bios) OVER ()) AS pct_bios
        FROM baseline
    ),
    edits_per_user AS (
        SELECT
          page_id,
          user_id,
          gender_lbl(gender) AS gender_cat,
          '3-edit' AS interaction_type,
          NULL as task_topic,
          CONCAT(YEAR(revision_timestamp),"-",MONTH(revision_timestamp),"-",DAY(revision_timestamp)) AS date
        FROM {newcomer_subset_tablename}
        WHERE
          wiki_db = '{wikidb}'
          AND gender IS NOT NULL
    ),
    actions_per_user AS (
        SELECT
          page_id,
          user_id,
          gender_lbl(gender) AS gender_cat,
          CASE
            WHEN interaction_type LIKE '%impression' THEN '1-impression'
            WHEN interaction_type LIKE '%click' THEN '2-click' 
            ELSE '0-unexpected'
          END AS interaction_type,
          CASE task_topic WHEN 'no-topic' THEN 'no-topic' ELSE 'topic' END AS task_topic,
          CONCAT(year, "-", month, "-", day) AS date
        FROM {events_subset_tablename}
        WHERE
          wiki_db = '{wikidb}'
          AND gender IS NOT NULL
    ),
    imputed_topics AS (
        SELECT
          page_id,
          user_id,
          gender_cat,
          interaction_type,
          LAST_VALUE(task_topic, TRUE) OVER w AS task_topic,
          date
        FROM (
            SELECT
              *
            FROM actions_per_user
            UNION ALL
            SELECT
              *
            FROM edits_per_user
        ) all
        WINDOW w AS (PARTITION BY page_id, user_id ORDER BY date ASC, interaction_type ASC ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW)    
    ),
    imputed_topics_counts AS (
        SELECT
          interaction_type,
          task_topic,
          gender_cat,
          COUNT(DISTINCT(user_id)) AS num_users,
          COUNT(1) AS num_events
        FROM imputed_topics
        WHERE
          task_topic IS NOT NULL
        GROUP BY
          interaction_type,
          task_topic,
          gender_cat
    )
    SELECT
      interaction_type,
      task_topic AS topic_filter,
      b.gender_cat AS gender,
      num_users,
      num_events,
      ROUND(num_events / SUM(num_events) OVER (PARTITION BY interaction_type, task_topic), 3) AS pct_events,
      ROUND(pct_bios, 3) AS pct_baseline
    FROM imputed_topics_counts i
    LEFT JOIN baseline_pct b
      ON (i.gender_cat = b.gender_cat)
    ORDER BY
      interaction_type,
      task_topic,
      num_events DESC
    """

    if do_execute:
        result = spark.sql(query)
        result.show(500, False)
# Out:
# == Analyzing fawiki ==
# +----------------+------------+------------------+---------+----------+----------+------------+
# |interaction_type|topic_filter|gender            |num_users|num_events|pct_events|pct_baseline|
# +----------------+------------+------------------+---------+----------+----------+------------+
# |1-impression    |no-topic    |male              |2205     |8693      |0.837     |0.788       |
# |1-impression    |no-topic    |female            |754      |1685      |0.162     |0.21        |
# |1-impression    |no-topic    |transgender female|2        |2         |0.0       |0.001       |
# |1-impression    |no-topic    |non-binary        |1        |1         |0.0       |0.0         |
# |1-impression    |topic       |male              |888      |8555      |0.79      |0.788       |
# |1-impression    |topic       |female            |464      |2265      |0.209     |0.21        |
# |1-impression    |topic       |non-binary        |4        |5         |0.0       |0.0         |
# |1-impression    |topic       |transgender female|1        |1         |0.0       |0.001       |
# |2-click         |no-topic    |male              |258      |596       |0.808     |0.788       |
# |2-click         |no-topic    |female            |73       |142       |0.192     |0.21        |
# |2-click         |topic       |male              |205      |640       |0.731     |0.788       |
# |2-click         |topic       |female            |81       |235       |0.269     |0.21        |
# |3-edit          |no-topic    |male              |133      |336       |0.783     |0.788       |
# |3-edit          |no-topic    |female            |49       |93        |0.217     |0.21        |
# |3-edit          |topic       |male              |115      |422       |0.74      |0.788       |
# |3-edit          |topic       |female            |46       |148       |0.26      |0.21        |
# +----------------+------------+------------------+---------+----------+----------+------------+
#
#
# == Analyzing ruwiki ==
# +----------------+------------+------------------+---------+----------+----------+------------+
# |interaction_type|topic_filter|gender            |num_users|num_events|pct_events|pct_baseline|
# +----------------+------------+------------------+---------+----------+----------+------------+
# |1-impression    |no-topic    |male              |2500     |10837     |0.801     |0.843       |
# |1-impression    |no-topic    |female            |1164     |2690      |0.199     |0.156       |
# |1-impression    |no-topic    |transgender female|5        |5         |0.0       |0.0         |
# |1-impression    |no-topic    |non-binary        |4        |4         |0.0       |0.0         |
# |1-impression    |topic       |male              |1219     |12046     |0.774     |0.843       |
# |1-impression    |topic       |female            |748      |3495      |0.225     |0.156       |
# |1-impression    |topic       |non-binary        |10       |10        |0.001     |0.0         |
# |1-impression    |topic       |transgender female|3        |3         |0.0       |0.0         |
# |1-impression    |topic       |transgender male  |1        |1         |0.0       |0.0         |
# |2-click         |no-topic    |male              |296      |551       |0.791     |0.843       |
# |2-click         |no-topic    |female            |100      |145       |0.208     |0.156       |
# |2-click         |no-topic    |transgender female|1        |1         |0.001     |0.0         |
# |2-click         |topic       |male              |285      |740       |0.747     |0.843       |
# |2-click         |topic       |female            |117      |250       |0.252     |0.156       |
# |2-click         |topic       |transgender female|1        |1         |0.001     |0.0         |
# |3-edit          |no-topic    |male              |163      |346       |0.812     |0.843       |
# |3-edit          |no-topic    |female            |53       |80        |0.188     |0.156       |
# |3-edit          |topic       |male              |165      |511       |0.767     |0.843       |
# |3-edit          |topic       |female            |68       |155       |0.233     |0.156       |
# +----------------+------------+------------------+---------+----------+----------+------------+
#
#
# == Analyzing frwiki ==
# +----------------+------------+------------------+---------+----------+----------+------------+
# |interaction_type|topic_filter|gender            |num_users|num_events|pct_events|pct_baseline|
# +----------------+------------+------------------+---------+----------+----------+------------+
# |1-impression    |no-topic    |male              |2692     |9969      |0.763     |0.809       |
# |1-impression    |no-topic    |female            |1317     |3069      |0.235     |0.19        |
# |1-impression    |no-topic    |transgender female|19       |20        |0.002     |0.0         |
# |1-impression    |no-topic    |non-binary        |9        |9         |0.001     |0.0         |
# |1-impression    |topic       |male              |1218     |10083     |0.726     |0.809       |
# |1-impression    |topic       |female            |783      |3762      |0.271     |0.19        |
# |1-impression    |topic       |transgender female|19       |28        |0.002     |0.0         |
# |1-impression    |topic       |non-binary        |9        |9         |0.001     |0.0         |
# |1-impression    |topic       |transgender male  |2        |3         |0.0       |0.0         |
# |2-click         |no-topic    |male              |303      |543       |0.748     |0.809       |
# |2-click         |no-topic    |female            |113      |180       |0.248     |0.19        |
# |2-click         |no-topic    |transgender female|3        |3         |0.004     |0.0         |
# |2-click         |topic       |male              |238      |663       |0.709     |0.809       |
# |2-click         |topic       |female            |125      |271       |0.29      |0.19        |
# |2-click         |topic       |transgender female|1        |1         |0.001     |0.0         |
# |3-edit          |no-topic    |male              |107      |266       |0.7       |0.809       |
# |3-edit          |no-topic    |female            |54       |114       |0.3       |0.19        |
# |3-edit          |topic       |male              |100      |380       |0.712     |0.809       |
# |3-edit          |topic       |female            |61       |153       |0.287     |0.19        |
# |3-edit          |topic       |transgender female|1        |1         |0.002     |0.0         |
# +----------------+------------+------------------+---------+----------+----------+------------+
#
#
# == Analyzing arwiki ==
# +----------------+------------+------------------+---------+----------+----------+------------+
# |interaction_type|topic_filter|gender            |num_users|num_events|pct_events|pct_baseline|
# +----------------+------------+------------------+---------+----------+----------+------------+
# |1-impression    |no-topic    |male              |3133     |9822      |0.714     |0.837       |
# |1-impression    |no-topic    |female            |1612     |3925      |0.285     |0.163       |
# |1-impression    |no-topic    |transgender female|5        |5         |0.0       |0.0         |
# |1-impression    |topic       |male              |1066     |6347      |0.676     |0.837       |
# |1-impression    |topic       |female            |668      |3032      |0.323     |0.163       |
# |1-impression    |topic       |transgender female|4        |4         |0.0       |0.0         |
# |1-impression    |topic       |non-binary        |1        |1         |0.0       |0.0         |
# |2-click         |no-topic    |male              |323      |532       |0.726     |0.837       |
# |2-click         |no-topic    |female            |128      |201       |0.274     |0.163       |
# |2-click         |topic       |male              |211      |538       |0.663     |0.837       |
# |2-click         |topic       |female            |117      |274       |0.337     |0.163       |
# |3-edit          |no-topic    |male              |120      |227       |0.739     |0.837       |
# |3-edit          |no-topic    |female            |43       |80        |0.261     |0.163       |
# |3-edit          |topic       |male              |91       |290       |0.67      |0.837       |
# |3-edit          |topic       |female            |50       |143       |0.33      |0.163       |
# +----------------+------------+------------------+---------+----------+----------+------------+

# %%
# geographic breakdown of edits by wiki
# 
# CTEs:
# * qids: gather all QIDs with a Wikipedia article in a given language
# * baseline: get count of articles for each country on wiki (articles with no countries ignored)
# * baseline_pct: convert counts into percentages
#    * NOTE: a single article can have many associated countries but the percentages are still normalized to add to 100%
#    *  so if e.g., 20% of geographic articles are attributed to UK here, it's maybe 30% of articles actually associated with the UK
# * regions_of_contrib: get edit data stratified by country from newcomer tasks
#    * If an article that was edited is associated with e.g., 3 countries, it'll show up 3 times, once with each country
# * ne_regions: compute counts stratified by geography
# * ne_regions_props: convert counts to percentages
# * SELECT: join together edit geo data and baseline geo data
# 
# NOTE: geographic baseline varies greatly by language though United States is usually top-3
# 
# NOTE: if desired, could use regions, continents, global north/south as geographic aggregations too
#   * Would just need to join against isaacj.country_to_region

print_for_hive = False
do_execute = True

for wikidb in wikis_with_stable_data:
    print(f"\n== Analyzing {wikidb} ==")
    query = f"""
    with qids AS (
        SELECT
          item_id
        FROM wmf.wikidata_item_page_link
        WHERE
          snapshot = '{wikidata_snapshot}'
          AND wiki_db = '{wikidb}'
          AND page_namespace = 0
    ),
    baseline AS (
        SELECT
          country,
          COUNT(DISTINCT(qid)) AS num_articles
        FROM {geo_table} g
        INNER JOIN qids q
          ON (g.qid = q.item_id)
        GROUP BY
          country
    ),
    baseline_pct AS (
        SELECT
          country,
          num_articles / (SUM(num_articles) OVER ()) AS pct_articles
        FROM baseline
    ),
    edits_per_user AS (
        SELECT
          page_id,
          user_id,
          EXPLODE(regions) AS country,
          '3-edit' AS interaction_type,
          NULL as task_topic,
          CONCAT(YEAR(revision_timestamp),"-",MONTH(revision_timestamp),"-",DAY(revision_timestamp)) AS date
        FROM {newcomer_subset_tablename}
        WHERE
          wiki_db = '{wikidb}'
          AND regions IS NOT NULL
          AND SIZE(regions) > 0
    ),
    actions_per_user AS (
        SELECT
          page_id,
          user_id,
          EXPLODE(regions) AS country,
          CASE
            WHEN interaction_type LIKE '%impression' THEN '1-impression'
            WHEN interaction_type LIKE '%click' THEN '2-click' 
            ELSE '0-unexpected'
          END AS interaction_type,
          CASE task_topic WHEN 'no-topic' THEN 'no-topic' ELSE 'topic' END AS task_topic,
          CONCAT(year, "-", month, "-", day) AS date
        FROM {events_subset_tablename}
        WHERE
          wiki_db = '{wikidb}'
          AND regions IS NOT NULL
          AND SIZE(regions) > 0
    ),
    imputed_topics AS (
        SELECT
          page_id,
          user_id,
          country,
          interaction_type,
          LAST_VALUE(task_topic, TRUE) OVER w AS task_topic,
          date
        FROM (
            SELECT
              *
            FROM actions_per_user
            UNION ALL
            SELECT
              *
            FROM edits_per_user
        ) all
        WINDOW w AS (PARTITION BY page_id, user_id ORDER BY date ASC, interaction_type ASC ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW)    
    ),
    imputed_topics_counts AS (
        SELECT
          interaction_type,
          task_topic,
          country,
          COUNT(DISTINCT(user_id)) AS num_users,
          COUNT(1) AS num_events
        FROM imputed_topics
        WHERE
          task_topic IS NOT NULL
        GROUP BY
          interaction_type,
          task_topic,
          country
    )
    SELECT
      interaction_type,
      task_topic AS topic_filter,
      i.country AS country,
      num_users,
      num_events,
      ROUND(num_events / SUM(num_events) OVER (PARTITION BY interaction_type, task_topic), 3) AS pct_events,
      ROUND(pct_articles, 3) AS pct_baseline
    FROM imputed_topics_counts i
    LEFT JOIN baseline_pct b
      ON (i.country = b.country)
    WHERE
      (pct_articles >= 0.01 OR num_events > 25)
    ORDER BY
      interaction_type,
      task_topic,
      num_events DESC
    """

    if do_execute:
        result = spark.sql(query)
        result.show(500, False)
# Out:
# == Analyzing fawiki ==
# +----------------+------------+------------------------------+---------+----------+----------+------------+
# |interaction_type|topic_filter|country                       |num_users|num_events|pct_events|pct_baseline|
# +----------------+------------+------------------------------+---------+----------+----------+------------+
# |1-impression    |no-topic    |Iran                          |1553     |4939      |0.237     |0.208       |
# |1-impression    |no-topic    |United States of America      |1301     |3944      |0.189     |0.193       |
# |1-impression    |no-topic    |United Kingdom                |694      |1449      |0.07      |0.052       |
# |1-impression    |no-topic    |France                        |437      |772       |0.037     |0.036       |
# |1-impression    |no-topic    |Japan                         |364      |725       |0.035     |0.028       |
# |1-impression    |no-topic    |Germany                       |332      |592       |0.028     |0.044       |
# |1-impression    |no-topic    |Italy                         |256      |407       |0.02      |0.031       |
# |1-impression    |no-topic    |Turkey                        |262      |404       |0.019     |0.01        |
# |1-impression    |no-topic    |Russia                        |251      |389       |0.019     |0.014       |
# |1-impression    |no-topic    |Australia                     |233      |366       |0.018     |0.012       |
# |1-impression    |no-topic    |Canada                        |196      |321       |0.015     |0.017       |
# |1-impression    |no-topic    |India                         |200      |306       |0.015     |0.017       |
# |1-impression    |no-topic    |Spain                         |169      |292       |0.014     |0.017       |
# |1-impression    |no-topic    |Afghanistan                   |204      |276       |0.013     |0.005       |
# |1-impression    |no-topic    |Israel                        |185      |260       |0.012     |0.003       |
# |1-impression    |no-topic    |Iraq                          |170      |257       |0.012     |0.003       |
# |1-impression    |no-topic    |Azerbaijan                    |157      |247       |0.012     |0.011       |
# |1-impression    |no-topic    |Egypt                         |165      |241       |0.012     |0.004       |
# |1-impression    |no-topic    |Brazil                        |135      |197       |0.009     |0.01        |
# |1-impression    |no-topic    |South Korea                   |140      |185       |0.009     |0.006       |
# |1-impression    |no-topic    |Switzerland                   |130      |175       |0.008     |0.006       |
# |1-impression    |no-topic    |China                         |127      |169       |0.008     |0.011       |
# |1-impression    |no-topic    |England                       |126      |168       |0.008     |0.017       |
# |1-impression    |no-topic    |Sweden                        |109      |141       |0.007     |0.008       |
# |1-impression    |no-topic    |Argentina                     |97       |133       |0.006     |0.005       |
# |1-impression    |no-topic    |Norway                        |83       |127       |0.006     |0.005       |
# |1-impression    |no-topic    |Pakistan                      |107      |127       |0.006     |0.006       |
# |1-impression    |topic       |Iceland                       |21       |32        |0.001     |0.001       |
# |1-impression    |topic       |Federated States of Micronesia|27       |31        |0.001     |0.0         |
# |1-impression    |topic       |Philippines                   |21       |31        |0.001     |0.002       |
# |1-impression    |topic       |Portugal                      |20       |30        |0.001     |0.002       |
# |1-impression    |topic       |Yemen                         |28       |30        |0.001     |0.003       |
# |1-impression    |topic       |Singapore                     |20       |30        |0.001     |0.001       |
# |1-impression    |topic       |Croatia                       |24       |29        |0.001     |0.002       |
# |1-impression    |topic       |Uruguay                       |20       |29        |0.001     |0.001       |
# |1-impression    |topic       |Czech Republic                |17       |28        |0.001     |0.011       |
# |1-impression    |topic       |Venezuela                     |18       |27        |0.001     |0.001       |
# |1-impression    |topic       |Tunisia                       |24       |27        |0.001     |0.001       |
# |2-click         |no-topic    |United States of America      |143      |362       |0.279     |0.193       |
# |2-click         |no-topic    |Iran                          |183      |337       |0.26      |0.208       |
# |2-click         |no-topic    |United Kingdom                |69       |118       |0.091     |0.052       |
# |2-click         |no-topic    |Japan                         |41       |84        |0.065     |0.028       |
# |2-click         |no-topic    |France                        |44       |64        |0.049     |0.036       |
# |2-click         |no-topic    |Canada                        |21       |37        |0.029     |0.017       |
# |2-click         |no-topic    |Germany                       |27       |36        |0.028     |0.044       |
# |2-click         |no-topic    |Italy                         |23       |33        |0.025     |0.031       |
# |2-click         |no-topic    |Russia                        |20       |31        |0.024     |0.014       |
# |2-click         |no-topic    |India                         |23       |29        |0.022     |0.017       |
# |2-click         |no-topic    |Afghanistan                   |23       |29        |0.022     |0.005       |
# |2-click         |no-topic    |Australia                     |22       |27        |0.021     |0.012       |
# |2-click         |no-topic    |Turkey                        |20       |26        |0.02      |0.01        |
# |2-click         |no-topic    |Azerbaijan                    |16       |20        |0.015     |0.011       |
# |2-click         |no-topic    |Spain                         |12       |16        |0.012     |0.017       |
# |2-click         |no-topic    |China                         |12       |15        |0.012     |0.011       |
# |2-click         |no-topic    |England                       |13       |14        |0.011     |0.017       |
# |2-click         |no-topic    |Poland                        |9        |13        |0.01      |0.023       |
# |2-click         |no-topic    |Czech Republic                |6        |6         |0.005     |0.011       |
# |2-click         |topic       |United States of America      |154      |750       |0.374     |0.193       |
# |2-click         |topic       |Iran                          |131      |285       |0.142     |0.208       |
# |2-click         |topic       |Japan                         |54       |193       |0.096     |0.028       |
# |2-click         |topic       |United Kingdom                |81       |186       |0.093     |0.052       |
# |2-click         |topic       |France                        |50       |82        |0.041     |0.036       |
# |2-click         |topic       |Russia                        |34       |55        |0.027     |0.014       |
# |2-click         |topic       |Canada                        |29       |54        |0.027     |0.017       |
# |2-click         |topic       |Australia                     |26       |52        |0.026     |0.012       |
# |2-click         |topic       |Germany                       |35       |50        |0.025     |0.044       |
# |2-click         |topic       |Italy                         |26       |47        |0.023     |0.031       |
# |2-click         |topic       |Brazil                        |25       |45        |0.022     |0.01        |
# |2-click         |topic       |Spain                         |21       |36        |0.018     |0.017       |
# |2-click         |topic       |Turkey                        |28       |35        |0.017     |0.01        |
# |2-click         |topic       |Egypt                         |19       |28        |0.014     |0.004       |
# |2-click         |topic       |China                         |17       |24        |0.012     |0.011       |
# |2-click         |topic       |England                       |18       |23        |0.011     |0.017       |
# |2-click         |topic       |Poland                        |16       |20        |0.01      |0.023       |
# |2-click         |topic       |Azerbaijan                    |14       |19        |0.009     |0.011       |
# |2-click         |topic       |India                         |15       |16        |0.008     |0.017       |
# |2-click         |topic       |Czech Republic                |2        |3         |0.001     |0.011       |
# |3-edit          |no-topic    |United States of America      |91       |232       |0.298     |0.193       |
# |3-edit          |no-topic    |Iran                          |86       |179       |0.23      |0.208       |
# |3-edit          |no-topic    |United Kingdom                |44       |79        |0.102     |0.052       |
# |3-edit          |no-topic    |France                        |33       |55        |0.071     |0.036       |
# |3-edit          |no-topic    |Japan                         |25       |52        |0.067     |0.028       |
# |3-edit          |no-topic    |Germany                       |18       |24        |0.031     |0.044       |
# |3-edit          |no-topic    |Italy                         |17       |22        |0.028     |0.031       |
# |3-edit          |no-topic    |Canada                        |13       |22        |0.028     |0.017       |
# |3-edit          |no-topic    |Russia                        |16       |21        |0.027     |0.014       |
# |3-edit          |no-topic    |Australia                     |13       |18        |0.023     |0.012       |
# |3-edit          |no-topic    |India                         |13       |18        |0.023     |0.017       |
# |3-edit          |no-topic    |Spain                         |12       |15        |0.019     |0.017       |
# |3-edit          |no-topic    |Azerbaijan                    |10       |13        |0.017     |0.011       |
# |3-edit          |no-topic    |China                         |10       |11        |0.014     |0.011       |
# |3-edit          |no-topic    |England                       |9        |9         |0.012     |0.017       |
# |3-edit          |no-topic    |Poland                        |4        |5         |0.006     |0.023       |
# |3-edit          |no-topic    |Czech Republic                |3        |3         |0.004     |0.011       |
# |3-edit          |topic       |United States of America      |99       |563       |0.408     |0.193       |
# |3-edit          |topic       |Iran                          |75       |208       |0.151     |0.208       |
# |3-edit          |topic       |United Kingdom                |53       |137       |0.099     |0.052       |
# |3-edit          |topic       |Japan                         |32       |129       |0.093     |0.028       |
# |3-edit          |topic       |France                        |33       |59        |0.043     |0.036       |
# |3-edit          |topic       |Russia                        |28       |43        |0.031     |0.014       |
# |3-edit          |topic       |Australia                     |15       |41        |0.03      |0.012       |
# |3-edit          |topic       |Canada                        |20       |40        |0.029     |0.017       |
# |3-edit          |topic       |Germany                       |24       |36        |0.026     |0.044       |
# |3-edit          |topic       |Italy                         |14       |25        |0.018     |0.031       |
# |3-edit          |topic       |Poland                        |15       |20        |0.014     |0.023       |
# |3-edit          |topic       |China                         |15       |20        |0.014     |0.011       |
# |3-edit          |topic       |Spain                         |11       |19        |0.014     |0.017       |
# |3-edit          |topic       |England                       |12       |16        |0.012     |0.017       |
# |3-edit          |topic       |India                         |8        |12        |0.009     |0.017       |
# |3-edit          |topic       |Azerbaijan                    |7        |9         |0.007     |0.011       |
# |3-edit          |topic       |Czech Republic                |2        |3         |0.002     |0.011       |
# +----------------+------------+------------------------------+---------+----------+----------+------------+
#
#
# == Analyzing ruwiki ==
# |1-impression    |topic       |Thailand                        |59       |83        |0.002     |0.001       |
# |1-impression    |topic       |Taiwan                          |45       |83        |0.002     |0.001       |
# |1-impression    |topic       |Pakistan                        |68       |79        |0.002     |0.002       |
# |1-impression    |topic       |Nepal                           |56       |78        |0.002     |0.001       |
# |1-impression    |topic       |Moldova                         |37       |77        |0.002     |0.003       |
# |1-impression    |topic       |Philippines                     |48       |77        |0.002     |0.001       |
# |1-impression    |topic       |Eritrea                         |36       |73        |0.002     |0.0         |
# |1-impression    |topic       |Croatia                         |42       |69        |0.002     |0.003       |
# |1-impression    |topic       |Kyrgyzstan                      |41       |69        |0.002     |0.002       |
# |1-impression    |topic       |Myanmar                         |44       |68        |0.002     |0.0         |
# |1-impression    |topic       |Nigeria                         |40       |68        |0.002     |0.001       |
# |1-impression    |topic       |Jordan                          |53       |65        |0.002     |0.0         |
# |1-impression    |topic       |Ghana                           |40       |61        |0.002     |0.001       |
# |1-impression    |topic       |Cuba                            |51       |59        |0.002     |0.001       |
# |1-impression    |topic       |Slovakia                        |33       |58        |0.002     |0.003       |
# |1-impression    |topic       |Morocco                         |28       |58        |0.002     |0.001       |
# |1-impression    |topic       |Bosnia and Herzegovina          |24       |57        |0.002     |0.002       |
# |1-impression    |topic       |Saint Vincent and the Grenadines|35       |54        |0.002     |0.0         |
# |1-impression    |topic       |Papua New Guinea                |44       |54        |0.002     |0.0         |
# |1-impression    |topic       |Syria                           |37       |50        |0.001     |0.001       |
# |1-impression    |topic       |Iceland                         |34       |49        |0.001     |0.001       |
# |1-impression    |topic       |Ethiopia                        |30       |48        |0.001     |0.001       |
# |1-impression    |topic       |Singapore                       |42       |48        |0.001     |0.0         |
# |1-impression    |topic       |The Bahamas                     |35       |47        |0.001     |0.0         |
# |1-impression    |topic       |Sri Lanka                       |25       |47        |0.001     |0.0         |
# |1-impression    |topic       |Bermuda                         |35       |45        |0.001     |0.0         |
# |1-impression    |topic       |Mongolia                        |25       |43        |0.001     |0.001       |
# |1-impression    |topic       |Colombia                        |33       |41        |0.001     |0.003       |
# |1-impression    |topic       |Jamaica                         |24       |40        |0.001     |0.0         |
# |1-impression    |topic       |Dominican Republic              |22       |40        |0.001     |0.0         |
# |1-impression    |topic       |Hong Kong                       |31       |39        |0.001     |0.001       |
# |1-impression    |topic       |Ecuador                         |28       |39        |0.001     |0.001       |
# |1-impression    |topic       |Haiti                           |27       |39        |0.001     |0.0         |
# |1-impression    |topic       |Turkmenistan                    |22       |38        |0.001     |0.001       |
# |1-impression    |topic       |Republic of the Congo           |25       |36        |0.001     |0.0         |
# |1-impression    |topic       |Saudi Arabia                    |27       |34        |0.001     |0.001       |
# |1-impression    |topic       |Chile                           |31       |34        |0.001     |0.002       |
# |1-impression    |topic       |Democratic Republic of the Congo|24       |32        |0.001     |0.001       |
# |1-impression    |topic       |Vietnam                         |22       |28        |0.001     |0.001       |
# |1-impression    |topic       |Cameroon                        |17       |28        |0.001     |0.001       |
# ...
# |1-impression    |topic       |Morocco                         |111      |225       |0.012     |0.05        |
# |1-impression    |topic       |Venezuela                       |39       |58        |0.003     |0.002       |
# |1-impression    |topic       |Pakistan                        |41       |56        |0.003     |0.002       |
# |1-impression    |topic       |Portugal                        |37       |55        |0.003     |0.005       |
# |1-impression    |topic       |Wales                           |42       |48        |0.002     |0.003       |
# |1-impression    |topic       |Cuba                            |36       |47        |0.002     |0.002       |
# |1-impression    |topic       |Oman                            |39       |46        |0.002     |0.005       |
# |1-impression    |topic       |Greece                          |34       |46        |0.002     |0.004       |
# |1-impression    |topic       |Bulgaria                        |34       |43        |0.002     |0.002       |
# |1-impression    |topic       |Belarus                         |20       |42        |0.002     |0.001       |
# |1-impression    |topic       |Romania                         |35       |42        |0.002     |0.003       |
# |1-impression    |topic       |Czech Republic                  |32       |42        |0.002     |0.002       |
# |1-impression    |topic       |Azerbaijan                      |32       |40        |0.002     |0.002       |
# |1-impression    |topic       |Uruguay                         |33       |38        |0.002     |0.002       |
# |1-impression    |topic       |North Korea                     |28       |37        |0.002     |0.001       |
# |1-impression    |topic       |Uzbekistan                      |25       |37        |0.002     |0.001       |
# |1-impression    |topic       |Serbia                          |29       |36        |0.002     |0.003       |
# |1-impression    |topic       |Puerto Rico                     |27       |34        |0.002     |0.0         |
# |1-impression    |topic       |Afghanistan                     |24       |32        |0.002     |0.001       |
# |1-impression    |topic       |Democratic Republic of the Congo|21       |31        |0.002     |0.001       |
# |1-impression    |topic       |Thailand                        |22       |31        |0.002     |0.001       |
# |1-impression    |topic       |Singapore                       |25       |31        |0.002     |0.001       |
# |1-impression    |topic       |Finland                         |25       |31        |0.002     |0.003       |
# |1-impression    |topic       |Georgia                         |25       |31        |0.002     |0.001       |
# |1-impression    |topic       |Guatemala                       |28       |31        |0.002     |0.001       |
# |1-impression    |topic       |Croatia                         |21       |30        |0.002     |0.002       |
# |1-impression    |topic       |Ghana                           |25       |30        |0.002     |0.001       |
# |1-impression    |topic       |Paraguay                        |24       |28        |0.001     |0.001       |
# |1-impression    |topic       |Scotland                        |18       |28        |0.001     |0.003       |
# |1-impression    |topic       |Costa Rica                      |23       |28        |0.001     |0.001       |
# |1-impression    |topic       |Vietnam                         |19       |28        |0.001     |0.001       |
# |1-impression    |topic       |Kenya                           |24       |27        |0.001     |0.001       |
# |1-impression    |topic       |Armenia                         |22       |27        |0.001     |0.001       |
# |1-impression    |topic       |Bolivia                         |23       |26        |0.001     |0.001       |
# |2-click         |no-topic    |United States of America        |193      |283       |0.317     |0.244       |
# |2-click         |no-topic    |Japan                           |72       |111       |0.124     |0.023       |
# |2-click         |no-topic    |United Kingdom                  |71       |91        |0.102     |0.071       |
# |2-click         |no-topic    |Egypt                           |44       |49        |0.055     |0.021       |
# |2-click         |no-topic    |France                          |40       |47        |0.053     |0.03        |
# |2-click         |no-topic    |Germany                         |44       |47        |0.053     |0.03        |
# |2-click         |no-topic    |Canada                          |33       |39        |0.044     |0.029       |
# |2-click         |no-topic    |Russia                          |28       |33        |0.037     |0.01        |
# |2-click         |no-topic    |Italy                           |28       |31        |0.035     |0.017       |
# |2-click         |no-topic    |Saudi Arabia                    |23       |28        |0.031     |0.014       |
# |2-click         |no-topic    |Syria                           |24       |27        |0.03      |0.011       |
# |2-click         |no-topic    |Australia                       |22       |25        |0.028     |0.024       |
# |2-click         |no-topic    |Spain                           |22       |23        |0.026     |0.022       |
# |2-click         |no-topic    |Brazil                          |20       |20        |0.022     |0.013       |
# |2-click         |no-topic    |Morocco                         |19       |20        |0.022     |0.05        |
# |2-click         |no-topic    |Iran                            |11       |11        |0.012     |0.038       |
# |2-click         |no-topic    |Yemen                           |7        |7         |0.008     |0.044       |
# |2-click         |topic       |United States of America        |163      |391       |0.348     |0.244       |
# |2-click         |topic       |Japan                           |81       |172       |0.153     |0.023       |
# |2-click         |topic       |United Kingdom                  |57       |111       |0.099     |0.071       |
# |2-click         |topic       |France                          |46       |56        |0.05      |0.03        |
# |2-click         |topic       |Egypt                           |41       |56        |0.05      |0.021       |
# |2-click         |topic       |Spain                           |32       |40        |0.036     |0.022       |
# |2-click         |topic       |Canada                          |31       |39        |0.035     |0.029       |
# |2-click         |topic       |Russia                          |28       |39        |0.035     |0.01        |
# |2-click         |topic       |Germany                         |31       |38        |0.034     |0.03        |
# |2-click         |topic       |Australia                       |20       |29        |0.026     |0.024       |
# |2-click         |topic       |Turkey                          |19       |26        |0.023     |0.006       |
# |2-click         |topic       |Brazil                          |18       |24        |0.021     |0.013       |
# |2-click         |topic       |Saudi Arabia                    |21       |24        |0.021     |0.014       |
# |2-click         |topic       |Italy                           |20       |23        |0.02      |0.017       |
# |2-click         |topic       |Morocco                         |19       |20        |0.018     |0.05        |
# |2-click         |topic       |Iran                            |10       |12        |0.011     |0.038       |
# |2-click         |topic       |Yemen                           |10       |11        |0.01      |0.044       |
# |2-click         |topic       |Syria                           |11       |11        |0.01      |0.011       |
# |3-edit          |no-topic    |United States of America        |77       |121       |0.33      |0.244       |
# |3-edit          |no-topic    |Japan                           |37       |50        |0.136     |0.023       |
# |3-edit          |no-topic    |United Kingdom                  |26       |36        |0.098     |0.071       |
# |3-edit          |no-topic    |Egypt                           |21       |23        |0.063     |0.021       |
# |3-edit          |no-topic    |Canada                          |12       |20        |0.054     |0.029       |
# |3-edit          |no-topic    |Germany                         |17       |19        |0.052     |0.03        |
# |3-edit          |no-topic    |France                          |14       |17        |0.046     |0.03        |
# |3-edit          |no-topic    |Saudi Arabia                    |9        |13        |0.035     |0.014       |
# |3-edit          |no-topic    |Australia                       |11       |12        |0.033     |0.024       |
# |3-edit          |no-topic    |Spain                           |12       |12        |0.033     |0.022       |
# |3-edit          |no-topic    |Italy                           |11       |11        |0.03      |0.017       |
# |3-edit          |no-topic    |Morocco                         |8        |8         |0.022     |0.05        |
# |3-edit          |no-topic    |Brazil                          |8        |8         |0.022     |0.013       |
# |3-edit          |no-topic    |Syria                           |6        |7         |0.019     |0.011       |
# |3-edit          |no-topic    |Iran                            |7        |7         |0.019     |0.038       |
# |3-edit          |no-topic    |Yemen                           |3        |3         |0.008     |0.044       |
# |3-edit          |topic       |United States of America        |82       |224       |0.379     |0.244       |
# |3-edit          |topic       |Japan                           |44       |93        |0.157     |0.023       |
# |3-edit          |topic       |United Kingdom                  |26       |60        |0.102     |0.071       |
# |3-edit          |topic       |France                          |23       |30        |0.051     |0.03        |
# |3-edit          |topic       |Russia                          |17       |26        |0.044     |0.01        |
# |3-edit          |topic       |Egypt                           |17       |25        |0.042     |0.021       |
# |3-edit          |topic       |Canada                          |17       |20        |0.034     |0.029       |
# |3-edit          |topic       |Spain                           |16       |17        |0.029     |0.022       |
# |3-edit          |topic       |Germany                         |13       |16        |0.027     |0.03        |
# |3-edit          |topic       |Australia                       |10       |14        |0.024     |0.024       |
# |3-edit          |topic       |Brazil                          |10       |14        |0.024     |0.013       |
# |3-edit          |topic       |Saudi Arabia                    |11       |13        |0.022     |0.014       |
# |3-edit          |topic       |Morocco                         |8        |12        |0.02      |0.05        |
# |3-edit          |topic       |Italy                           |11       |12        |0.02      |0.017       |
# |3-edit          |topic       |Iran                            |5        |6         |0.01      |0.038       |
# |3-edit          |topic       |Syria                           |6        |6         |0.01      |0.011       |
# |3-edit          |topic       |Yemen                           |2        |3         |0.005     |0.044       |
# +----------------+------------+--------------------------------+---------+----------+----------+------------+

# %% [markdown]
# ## Ad-hoc Analyses

# %% [markdown]
# ### EventLogging loss

# %%
# How well can we impute topic for edits based on clicks/impressions?
# Some small percentage of edits lack eventlogging (presumably ad-blockers mainly)
# Hopefully this isn't too high -- e..g, much above 10% -- or biased (though hard to measure that)

# NOTE: the complicated window function below does the following:
#   * it orders all the events between a given user + article chronologically (with impressions then clicks then edits when a date is shared)
#   * for each topic row, it starts with that rows value and begins walking towards the start of the list. The first non-null value is retained.
#   * So if there's already a topic, it's kept. If there isn't -- i.e. for edit data -- it takes the most recent topic for that user+article (from the click/impression data)
print_for_hive = False
do_execute = True

query = f"""
with edits_per_user AS (
    SELECT
      wiki_db,
      page_id,
      user_id,
      '3-edit' AS interaction_type,
      NULL as task_topic,
      CONCAT(YEAR(revision_timestamp),"-",MONTH(revision_timestamp),"-",DAY(revision_timestamp)) AS date
    FROM {newcomer_subset_tablename}
),
actions_per_user AS (
    SELECT
      wiki_db,
      page_id,
      user_id,
      CASE
        WHEN interaction_type LIKE '%impression' THEN '1-impression'
        WHEN interaction_type LIKE '%click' THEN '2-click' 
        ELSE '0-unexpected'
      END AS interaction_type,
      task_topic,
      CONCAT(year, "-", month, "-", day) AS date
    FROM {events_subset_tablename}
),
imputed_topics AS (
    SELECT
      wiki_db,
      page_id,
      user_id,
      interaction_type,
      LAST_VALUE(task_topic, TRUE) OVER w AS task_topic,
      date
    FROM (
        SELECT
          *
        FROM actions_per_user
        UNION ALL
        SELECT
          *
        FROM edits_per_user
    ) all
    WINDOW w AS (PARTITION BY wiki_db, page_id, user_id ORDER BY date ASC, interaction_type ASC ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW)    
)
SELECT
  wiki_db,
  interaction_type,
  COUNT(1) AS num_rows,
  SUM(IF(ISNULL(task_topic), 1, 0)) AS num_nulls,
  ROUND(SUM(IF(ISNULL(task_topic), 1, 0)) / COUNT(1), 3) AS pct_null
FROM imputed_topics
GROUP BY
  wiki_db,
  interaction_type
ORDER BY
  wiki_db,
  interaction_type
"""

if print_for_hive:
    print(re.sub(' +', ' ', re.sub('\n', ' ', query)).strip())
else:
    print(query)

if do_execute:
    result = spark.sql(query)
    result.show(500, False)
# Out:
# with edits_per_user AS (
#     SELECT
#       wiki_db,
#       page_id,
#       user_id,
#       '3-edit' AS interaction_type,
#       NULL as task_topic,
#       CONCAT(YEAR(revision_timestamp),"-",MONTH(revision_timestamp),"-",DAY(revision_timestamp)) AS date
#     FROM isaacj.newcomer_tasks
# ),
# actions_per_user AS (
#     SELECT
#       wiki_db,
#       page_id,
#       user_id,
#       CASE
#         WHEN interaction_type LIKE '%impression' THEN '1-impression'
#         WHEN interaction_type LIKE '%click' THEN '2-click'
#         ELSE '0-unexpected'
#       END AS interaction_type,
#       task_topic,
#       CONCAT(year, "-", month, "-", day) AS date
#     FROM isaacj.newcomer_tasks_events
# ),
# imputed_topics AS (
#     SELECT
#       wiki_db,
#       page_id,
#       user_id,
#       interaction_type,
#       LAST_VALUE(task_topic, TRUE) OVER w AS task_topic,
#       date
#     FROM (
#         SELECT
#           *
#         FROM actions_per_user
#         UNION ALL
#         SELECT
#           *
#         FROM edits_per_user
#     ) all
#     WINDOW w AS (PARTITION BY wiki_db, page_id, user_id ORDER BY date ASC, interaction_type ASC ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW)
# )
# SELECT
#   wiki_db,
#   interaction_type,
#   COUNT(1) AS num_rows,
#   SUM(IF(ISNULL(task_topic), 1, 0)) AS num_nulls
# FROM imputed_topics
# GROUP BY
#   wiki_db,
#   interaction_type
# ORDER BY
#   wiki_db,
#   interaction_type
#
# +-------+----------------+--------+---------+
# |wiki_db|interaction_type|num_rows|num_nulls|
# +-------+----------------+--------+---------+
# |arwiki |1-impression    |84877   |0        |
# |arwiki |2-click         |5939    |0        |
# |arwiki |3-edit          |3206    |95       |
# |cswiki |1-impression    |20578   |0        |
# |cswiki |2-click         |1761    |0        |
# |cswiki |3-edit          |736     |52       |
# |euwiki |1-impression    |856     |0        |
# |euwiki |2-click         |49      |0        |
# |euwiki |3-edit          |15      |0        |
# |fawiki |1-impression    |89569   |0        |
# |fawiki |2-click         |7901    |0        |
# |fawiki |3-edit          |5763    |347      |
# |frwiki |1-impression    |83411   |0        |
# |frwiki |2-click         |5616    |0        |
# |frwiki |3-edit          |3752    |638      |
# |hewiki |1-impression    |28081   |0        |
# |hewiki |2-click         |982     |0        |
# |hewiki |3-edit          |475     |37       |
# |huwiki |1-impression    |16671   |0        |
# |huwiki |2-click         |2050    |0        |
# |huwiki |3-edit          |1662    |8        |
# |hywiki |1-impression    |4653    |0        |
# |hywiki |2-click         |123     |0        |
# |hywiki |3-edit          |47      |1        |
# |kowiki |1-impression    |19604   |0        |
# |kowiki |2-click         |925     |0        |
# |kowiki |3-edit          |550     |9        |
# |plwiki |1-impression    |41120   |0        |
# |plwiki |2-click         |2878    |0        |
# |plwiki |3-edit          |1817    |87       |
# |ptwiki |1-impression    |74302   |0        |
# |ptwiki |2-click         |3097    |0        |
# |ptwiki |3-edit          |1788    |222      |
# |ruwiki |1-impression    |111835  |0        |
# |ruwiki |2-click         |7182    |0        |
# |ruwiki |3-edit          |4667    |400      |
# |srwiki |1-impression    |4332    |0        |
# |srwiki |2-click         |104     |0        |
# |srwiki |3-edit          |52      |5        |
# |svwiki |1-impression    |7174    |0        |
# |svwiki |2-click         |356     |0        |
# |svwiki |3-edit          |173     |12       |
# |trwiki |1-impression    |42845   |0        |
# |trwiki |2-click         |1575    |0        |
# |trwiki |3-edit          |623     |81       |
# |ukwiki |1-impression    |17672   |0        |
# |ukwiki |2-click         |880     |0        |
# |ukwiki |3-edit          |1115    |88       |
# |viwiki |1-impression    |38768   |0        |
# |viwiki |2-click         |3349    |0        |
# |viwiki |3-edit          |2133    |140      |
# +-------+----------------+--------+---------+

# %% [markdown]
# ### Relative Distribution of Each Task Type

# %%
# Breakdown of edits by types (imputed)
# Similar logic to above EventLogging audit
print_for_hive = False
do_execute = True

query = f"""
with edits_per_user AS (
    SELECT
      wiki_db,
      page_id,
      user_id,
      '3-edit' AS interaction_type,
      NULL as task_type,
      CONCAT(YEAR(revision_timestamp),"-",MONTH(revision_timestamp),"-",DAY(revision_timestamp)) AS date
    FROM {newcomer_subset_tablename}
),
actions_per_user AS (
    SELECT
      wiki_db,
      page_id,
      user_id,
      CASE
        WHEN interaction_type LIKE '%impression' THEN '1-impression'
        WHEN interaction_type LIKE '%click' THEN '2-click' 
        ELSE '0-unexpected'
      END AS interaction_type,
      task_type,
      CONCAT(year, "-", month, "-", day) AS date
    FROM {events_subset_tablename}
),
imputed_types AS (
    SELECT
      wiki_db,
      page_id,
      user_id,
      interaction_type,
      LAST_VALUE(task_type, TRUE) OVER w AS task_type,
      date
    FROM (
        SELECT
          *
        FROM actions_per_user
        UNION ALL
        SELECT
          *
        FROM edits_per_user
    ) all
    WINDOW w AS (PARTITION BY wiki_db, page_id, user_id ORDER BY date ASC, interaction_type ASC ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW)    
),
action_counts AS (
    SELECT
      wiki_db,
      interaction_type,
      task_type,
      COUNT(1) AS num_actions
    FROM imputed_types
    GROUP BY
      wiki_db,
      interaction_type,
      task_type
)
SELECT
  wiki_db,
  interaction_type,
  task_type,
  num_actions,
  ROUND(num_actions / SUM(num_actions) OVER (PARTITION BY wiki_db, interaction_type), 3) AS pct_actions
FROM action_counts
WHERE
  task_type IS NOT NULL
ORDER BY
  wiki_db,
  task_type,
  interaction_type
"""

if print_for_hive:
    print(re.sub(' +', ' ', re.sub('\n', ' ', query)).strip())
else:
    print(query)

if do_execute:
    result = spark.sql(query)
    result.show(500, False)
# Out:
# with edits_per_user AS (
#     SELECT
#       wiki_db,
#       page_id,
#       user_id,
#       '3-edit' AS interaction_type,
#       NULL as task_type,
#       CONCAT(YEAR(revision_timestamp),"-",MONTH(revision_timestamp),"-",DAY(revision_timestamp)) AS date
#     FROM isaacj.newcomer_tasks
# ),
# actions_per_user AS (
#     SELECT
#       wiki_db,
#       page_id,
#       user_id,
#       CASE
#         WHEN interaction_type LIKE '%impression' THEN '1-impression'
#         WHEN interaction_type LIKE '%click' THEN '2-click'
#         ELSE '0-unexpected'
#       END AS interaction_type,
#       task_type,
#       CONCAT(year, "-", month, "-", day) AS date
#     FROM isaacj.newcomer_tasks_events
# ),
# imputed_types AS (
#     SELECT
#       wiki_db,
#       page_id,
#       user_id,
#       interaction_type,
#       LAST_VALUE(task_type, TRUE) OVER w AS task_type,
#       date
#     FROM (
#         SELECT
#           *
#         FROM actions_per_user
#         UNION ALL
#         SELECT
#           *
#         FROM edits_per_user
#     ) all
#     WINDOW w AS (PARTITION BY wiki_db, page_id, user_id ORDER BY date ASC, interaction_type ASC ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW)
# ),
# action_counts AS (
#     SELECT
#       wiki_db,
#       interaction_type,
#       task_type,
#       COUNT(1) AS num_actions
#     FROM imputed_types
#     GROUP BY
#       wiki_db,
#       interaction_type,
#       task_type
# )
# SELECT
#   wiki_db,
#   interaction_type,
#   task_type,
#   num_actions,
#   ROUND(num_actions / SUM(num_actions) OVER (PARTITION BY wiki_db, interaction_type), 3) AS pct_actions
# FROM action_counts
# ORDER BY
#   wiki_db,
#   task_type,
#   interaction_type
#
# +-------+----------------+-------------------+-----------+-----------+
# |wiki_db|interaction_type|task_type          |num_actions|pct_actions|
# +-------+----------------+-------------------+-----------+-----------+
# |arwiki |3-edit          |null               |95         |0.03       |
# |arwiki |1-impression    |copyedit           |17696      |0.208      |
# |arwiki |2-click         |copyedit           |1107       |0.186      |
# |arwiki |3-edit          |copyedit           |412        |0.129      |
# |arwiki |1-impression    |expand             |5325       |0.063      |
# |arwiki |2-click         |expand             |237        |0.04       |
# |arwiki |3-edit          |expand             |101        |0.032      |
# |arwiki |1-impression    |link-recommendation|39016      |0.46       |
# |arwiki |2-click         |link-recommendation|3545       |0.597      |
# |arwiki |3-edit          |link-recommendation|2251       |0.702      |
# |arwiki |1-impression    |links              |13612      |0.16       |
# |arwiki |2-click         |links              |740        |0.125      |
# |arwiki |3-edit          |links              |240        |0.075      |
# |arwiki |1-impression    |references         |7192       |0.085      |
# |arwiki |2-click         |references         |214        |0.036      |
# |arwiki |3-edit          |references         |82         |0.026      |
# |arwiki |1-impression    |update             |2036       |0.024      |
# |arwiki |2-click         |update             |96         |0.016      |
# |arwiki |3-edit          |update             |25         |0.008      |
# |cswiki |3-edit          |null               |52         |0.071      |
# |cswiki |1-impression    |copyedit           |5880       |0.286      |
# |cswiki |2-click         |copyedit           |297        |0.169      |
# |cswiki |3-edit          |copyedit           |53         |0.072      |
# |cswiki |1-impression    |expand             |1881       |0.091      |
# |cswiki |2-click         |expand             |79         |0.045      |
# |cswiki |3-edit          |expand             |10         |0.014      |
# |cswiki |1-impression    |link-recommendation|8284       |0.403      |
# |cswiki |2-click         |link-recommendation|1227       |0.697      |
# |cswiki |3-edit          |link-recommendation|587        |0.798      |
# |cswiki |1-impression    |links              |916        |0.045      |
# |cswiki |2-click         |links              |24         |0.014      |
# |cswiki |3-edit          |links              |6          |0.008      |
# |cswiki |1-impression    |references         |1368       |0.066      |
# |cswiki |2-click         |references         |60         |0.034      |
# |cswiki |3-edit          |references         |17         |0.023      |
# |cswiki |1-impression    |update             |2249       |0.109      |
# |cswiki |2-click         |update             |74         |0.042      |
# |cswiki |3-edit          |update             |11         |0.015      |
# |euwiki |1-impression    |copyedit           |312        |0.364      |
# |euwiki |2-click         |copyedit           |27         |0.551      |
# |euwiki |3-edit          |copyedit           |7          |0.467      |
# |euwiki |1-impression    |expand             |218        |0.255      |
# |euwiki |2-click         |expand             |5          |0.102      |
# |euwiki |1-impression    |links              |214        |0.25       |
# |euwiki |2-click         |links              |15         |0.306      |
# |euwiki |3-edit          |links              |6          |0.4        |
# |euwiki |1-impression    |references         |91         |0.106      |
# |euwiki |2-click         |references         |2          |0.041      |
# |euwiki |3-edit          |references         |2          |0.133      |
# |euwiki |1-impression    |update             |21         |0.025      |
# |fawiki |3-edit          |null               |347        |0.06       |
# |fawiki |1-impression    |copyedit           |18146      |0.203      |
# |fawiki |2-click         |copyedit           |1203       |0.152      |
# |fawiki |3-edit          |copyedit           |597        |0.104      |
# |fawiki |1-impression    |expand             |7235       |0.081      |
# |fawiki |2-click         |expand             |243        |0.031      |
# |fawiki |3-edit          |expand             |143        |0.025      |
# |fawiki |1-impression    |link-recommendation|27897      |0.311      |
# |fawiki |2-click         |link-recommendation|4581       |0.58       |
# |fawiki |3-edit          |link-recommendation|3475       |0.603      |
# |fawiki |1-impression    |links              |26324      |0.294      |
# |fawiki |2-click         |links              |1496       |0.189      |
# |fawiki |3-edit          |links              |928        |0.161      |
# |fawiki |1-impression    |references         |6831       |0.076      |
# |fawiki |2-click         |references         |251        |0.032      |
# |fawiki |3-edit          |references         |226        |0.039      |
# |fawiki |1-impression    |update             |3136       |0.035      |
# |fawiki |2-click         |update             |127        |0.016      |
# |fawiki |3-edit          |update             |47         |0.008      |
# |frwiki |3-edit          |null               |638        |0.17       |
# |frwiki |1-impression    |copyedit           |27483      |0.329      |
# |frwiki |2-click         |copyedit           |1446       |0.257      |
# |frwiki |3-edit          |copyedit           |504        |0.134      |
# |frwiki |1-impression    |expand             |4439       |0.053      |
# |frwiki |2-click         |expand             |108        |0.019      |
# |frwiki |3-edit          |expand             |27         |0.007      |
# |frwiki |1-impression    |link-recommendation|22283      |0.267      |
# |frwiki |2-click         |link-recommendation|2886       |0.514      |
# |frwiki |3-edit          |link-recommendation|2113       |0.563      |
# |frwiki |1-impression    |links              |19878      |0.238      |
# |frwiki |2-click         |links              |869        |0.155      |
# |frwiki |3-edit          |links              |361        |0.096      |
# |frwiki |1-impression    |references         |4556       |0.055      |
# |frwiki |2-click         |references         |174        |0.031      |
# |frwiki |3-edit          |references         |81         |0.022      |
# |frwiki |1-impression    |update             |4772       |0.057      |
# |frwiki |2-click         |update             |133        |0.024      |
# |frwiki |3-edit          |update             |28         |0.007      |
# |hewiki |3-edit          |null               |37         |0.078      |
# |hewiki |1-impression    |copyedit           |19248      |0.685      |
# |hewiki |2-click         |copyedit           |731        |0.744      |
# |hewiki |3-edit          |copyedit           |349        |0.735      |
# |hewiki |1-impression    |expand             |4867       |0.173      |
# |hewiki |2-click         |expand             |105        |0.107      |
# |hewiki |3-edit          |expand             |34         |0.072      |
# |hewiki |1-impression    |links              |90         |0.003      |
# |hewiki |2-click         |links              |11         |0.011      |
# |hewiki |3-edit          |links              |5          |0.011      |
# |hewiki |1-impression    |references         |1443       |0.051      |
# |hewiki |2-click         |references         |66         |0.067      |
# |hewiki |3-edit          |references         |14         |0.029      |
# |hewiki |1-impression    |update             |2433       |0.087      |
# |hewiki |2-click         |update             |69         |0.07       |
# |hewiki |3-edit          |update             |36         |0.076      |
# |huwiki |3-edit          |null               |8          |0.005      |
# |huwiki |1-impression    |copyedit           |3521       |0.211      |
# |huwiki |2-click         |copyedit           |150        |0.073      |
# |huwiki |3-edit          |copyedit           |45         |0.027      |
# |huwiki |1-impression    |expand             |925        |0.055      |
# |huwiki |2-click         |expand             |15         |0.007      |
# |huwiki |3-edit          |expand             |1          |0.001      |
# |huwiki |1-impression    |link-recommendation|8990       |0.539      |
# |huwiki |2-click         |link-recommendation|1799       |0.878      |
# |huwiki |3-edit          |link-recommendation|1578       |0.949      |
# |huwiki |1-impression    |links              |1813       |0.109      |
# |huwiki |2-click         |links              |46         |0.022      |
# |huwiki |3-edit          |links              |12         |0.007      |
# |huwiki |1-impression    |references         |639        |0.038      |
# |huwiki |2-click         |references         |21         |0.01       |
# |huwiki |3-edit          |references         |6          |0.004      |
# |huwiki |1-impression    |update             |783        |0.047      |
# |huwiki |2-click         |update             |19         |0.009      |
# |huwiki |3-edit          |update             |12         |0.007      |
# |hywiki |3-edit          |null               |1          |0.021      |
# |hywiki |1-impression    |expand             |1096       |0.236      |
# |hywiki |2-click         |expand             |22         |0.179      |
# |hywiki |3-edit          |expand             |12         |0.255      |
# |hywiki |1-impression    |links              |2629       |0.565      |
# |hywiki |2-click         |links              |58         |0.472      |
# |hywiki |3-edit          |links              |25         |0.532      |
# |hywiki |1-impression    |references         |366        |0.079      |
# |hywiki |2-click         |references         |20         |0.163      |
# |hywiki |3-edit          |references         |7          |0.149      |
# |hywiki |1-impression    |update             |562        |0.121      |
# |hywiki |2-click         |update             |23         |0.187      |
# |hywiki |3-edit          |update             |2          |0.043      |
# |kowiki |3-edit          |null               |9          |0.016      |
# |kowiki |1-impression    |copyedit           |13076      |0.667      |
# |kowiki |2-click         |copyedit           |668        |0.722      |
# |kowiki |3-edit          |copyedit           |397        |0.722      |
# |kowiki |1-impression    |expand             |2849       |0.145      |
# |kowiki |2-click         |expand             |127        |0.137      |
# |kowiki |3-edit          |expand             |75         |0.136      |
# |kowiki |1-impression    |references         |1789       |0.091      |
# |kowiki |2-click         |references         |49         |0.053      |
# |kowiki |3-edit          |references         |19         |0.035      |
# |kowiki |1-impression    |update             |1890       |0.096      |
# |kowiki |2-click         |update             |81         |0.088      |
# |kowiki |3-edit          |update             |50         |0.091      |
# |plwiki |3-edit          |null               |87         |0.048      |
# |plwiki |1-impression    |copyedit           |12579      |0.306      |
# |plwiki |2-click         |copyedit           |565        |0.196      |
# |plwiki |3-edit          |copyedit           |149        |0.082      |
# |plwiki |1-impression    |expand             |2767       |0.067      |
# |plwiki |2-click         |expand             |79         |0.027      |
# |plwiki |3-edit          |expand             |12         |0.007      |
# |plwiki |1-impression    |link-recommendation|14018      |0.341      |
# |plwiki |2-click         |link-recommendation|1396       |0.485      |
# |plwiki |3-edit          |link-recommendation|1428       |0.786      |
# |plwiki |1-impression    |links              |2124       |0.052      |
# |plwiki |2-click         |links              |94         |0.033      |
# |plwiki |3-edit          |links              |57         |0.031      |
# |plwiki |1-impression    |references         |6619       |0.161      |
# |plwiki |2-click         |references         |693        |0.241      |
# |plwiki |3-edit          |references         |68         |0.037      |
# |plwiki |1-impression    |update             |3013       |0.073      |
# |plwiki |2-click         |update             |51         |0.018      |
# |plwiki |3-edit          |update             |16         |0.009      |
# |ptwiki |3-edit          |null               |222        |0.124      |
# |ptwiki |1-impression    |copyedit           |32093      |0.432      |
# |ptwiki |2-click         |copyedit           |1587       |0.512      |
# |ptwiki |3-edit          |copyedit           |873        |0.488      |
# |ptwiki |1-impression    |expand             |4550       |0.061      |
# |ptwiki |2-click         |expand             |85         |0.027      |
# |ptwiki |3-edit          |expand             |27         |0.015      |
# |ptwiki |1-impression    |links              |28760      |0.387      |
# |ptwiki |2-click         |links              |1208       |0.39       |
# |ptwiki |3-edit          |links              |535        |0.299      |
# |ptwiki |1-impression    |references         |5107       |0.069      |
# |ptwiki |2-click         |references         |104        |0.034      |
# |ptwiki |3-edit          |references         |93         |0.052      |
# |ptwiki |1-impression    |update             |3792       |0.051      |
# |ptwiki |2-click         |update             |113        |0.036      |
# |ptwiki |3-edit          |update             |38         |0.021      |
# |ruwiki |3-edit          |null               |400        |0.086      |
# |ruwiki |1-impression    |copyedit           |20255      |0.181      |
# |ruwiki |2-click         |copyedit           |1183       |0.165      |
# |ruwiki |3-edit          |copyedit           |429        |0.092      |
# |ruwiki |1-impression    |expand             |13327      |0.119      |
# |ruwiki |2-click         |expand             |274        |0.038      |
# |ruwiki |3-edit          |expand             |152        |0.033      |
# |ruwiki |1-impression    |link-recommendation|28507      |0.255      |
# |ruwiki |2-click         |link-recommendation|3205       |0.446      |
# |ruwiki |3-edit          |link-recommendation|2318       |0.497      |
# |ruwiki |1-impression    |links              |31569      |0.282      |
# |ruwiki |2-click         |links              |1879       |0.262      |
# |ruwiki |3-edit          |links              |1063       |0.228      |
# |ruwiki |1-impression    |references         |8131       |0.073      |
# |ruwiki |2-click         |references         |278        |0.039      |
# |ruwiki |3-edit          |references         |141        |0.03       |
# |ruwiki |1-impression    |update             |10046      |0.09       |
# |ruwiki |2-click         |update             |363        |0.051      |
# |ruwiki |3-edit          |update             |164        |0.035      |
# |srwiki |3-edit          |null               |5          |0.096      |
# |srwiki |1-impression    |copyedit           |2362       |0.545      |
# |srwiki |2-click         |copyedit           |58         |0.558      |
# |srwiki |3-edit          |copyedit           |29         |0.558      |
# |srwiki |1-impression    |expand             |178        |0.041      |
# |srwiki |2-click         |expand             |3          |0.029      |
# |srwiki |3-edit          |expand             |2          |0.038      |
# |srwiki |1-impression    |links              |1587       |0.366      |
# |srwiki |2-click         |links              |38         |0.365      |
# |srwiki |3-edit          |links              |15         |0.288      |
# |srwiki |1-impression    |references         |62         |0.014      |
# |srwiki |2-click         |references         |1          |0.01       |
# |srwiki |1-impression    |update             |143        |0.033      |
# |srwiki |2-click         |update             |4          |0.038      |
# |srwiki |3-edit          |update             |1          |0.019      |
# |svwiki |3-edit          |null               |12         |0.069      |
# |svwiki |1-impression    |copyedit           |5064       |0.706      |
# |svwiki |2-click         |copyedit           |291        |0.817      |
# |svwiki |3-edit          |copyedit           |137        |0.792      |
# |svwiki |1-impression    |expand             |86         |0.012      |
# |svwiki |2-click         |expand             |6          |0.017      |
# |svwiki |1-impression    |links              |7          |0.001      |
# |svwiki |1-impression    |references         |898        |0.125      |
# |svwiki |2-click         |references         |24         |0.067      |
# |svwiki |3-edit          |references         |15         |0.087      |
# |svwiki |1-impression    |update             |1119       |0.156      |
# |svwiki |2-click         |update             |35         |0.098      |
# |svwiki |3-edit          |update             |9          |0.052      |
# |trwiki |3-edit          |null               |81         |0.13       |
# |trwiki |1-impression    |copyedit           |16110      |0.376      |
# |trwiki |2-click         |copyedit           |677        |0.43       |
# |trwiki |3-edit          |copyedit           |202        |0.324      |
# |trwiki |1-impression    |expand             |3049       |0.071      |
# |trwiki |2-click         |expand             |58         |0.037      |
# |trwiki |3-edit          |expand             |20         |0.032      |
# |trwiki |1-impression    |links              |18033      |0.421      |
# |trwiki |2-click         |links              |691        |0.439      |
# |trwiki |3-edit          |links              |271        |0.435      |
# |trwiki |1-impression    |references         |2672       |0.062      |
# |trwiki |2-click         |references         |50         |0.032      |
# |trwiki |3-edit          |references         |15         |0.024      |
# |trwiki |1-impression    |update             |2981       |0.07       |
# |trwiki |2-click         |update             |99         |0.063      |
# |trwiki |3-edit          |update             |34         |0.055      |
# |ukwiki |3-edit          |null               |88         |0.079      |
# |ukwiki |1-impression    |copyedit           |9410       |0.532      |
# |ukwiki |2-click         |copyedit           |483        |0.549      |
# |ukwiki |3-edit          |copyedit           |629        |0.564      |
# |ukwiki |1-impression    |expand             |1057       |0.06       |
# |ukwiki |2-click         |expand             |22         |0.025      |
# |ukwiki |3-edit          |expand             |5          |0.004      |
# |ukwiki |1-impression    |links              |4787       |0.271      |
# |ukwiki |2-click         |links              |318        |0.361      |
# |ukwiki |3-edit          |links              |369        |0.331      |
# |ukwiki |1-impression    |references         |1143       |0.065      |
# |ukwiki |2-click         |references         |24         |0.027      |
# |ukwiki |3-edit          |references         |12         |0.011      |
# |ukwiki |1-impression    |update             |1275       |0.072      |
# |ukwiki |2-click         |update             |33         |0.038      |
# |ukwiki |3-edit          |update             |12         |0.011      |
# |viwiki |3-edit          |null               |140        |0.066      |
# |viwiki |1-impression    |copyedit           |9151       |0.236      |
# |viwiki |2-click         |copyedit           |518        |0.155      |
# |viwiki |3-edit          |copyedit           |187        |0.088      |
# |viwiki |1-impression    |expand             |4596       |0.119      |
# |viwiki |2-click         |expand             |115        |0.034      |
# |viwiki |3-edit          |expand             |258        |0.121      |
# |viwiki |1-impression    |link-recommendation|16599      |0.428      |
# |viwiki |2-click         |link-recommendation|2349       |0.701      |
# |viwiki |3-edit          |link-recommendation|1439       |0.675      |
# |viwiki |1-impression    |links              |3497       |0.09       |
# |viwiki |2-click         |links              |187        |0.056      |
# |viwiki |3-edit          |links              |48         |0.023      |
# |viwiki |1-impression    |references         |3004       |0.077      |
# |viwiki |2-click         |references         |103        |0.031      |
# |viwiki |3-edit          |references         |36         |0.017      |
# |viwiki |1-impression    |update             |1921       |0.05       |
# |viwiki |2-click         |update             |77         |0.023      |
# |viwiki |3-edit          |update             |25         |0.012      |
# +-------+----------------+-------------------+-----------+-----------+

# %% [markdown]
# ### Power User Examination

# %%
# power analysis by wiki -- i.e. do we have users who contribute a lot of data (and so we should be suspicious of conclusions)

print_for_hive = False
do_execute = True

query = f"""
with actions AS (
    SELECT
      wiki_db,
      user_id,
      CASE
        WHEN interaction_type LIKE '%impression' THEN '1-impression'
        WHEN interaction_type LIKE '%click' THEN '2-click'
        ELSE interaction_type
      END AS interaction_type
    FROM {events_subset_tablename}
),
actions_per_user AS (
    SELECT
      wiki_db,
      user_id,
      interaction_type,
      COUNT(1) AS num_events
    FROM actions
    GROUP BY
      wiki_db,
      user_id,
      interaction_type
),
edits_per_user AS (
    SELECT
      wiki_db,
      user_id,
      COUNT(1) AS num_events
    FROM {newcomer_subset_tablename}
    GROUP BY
      wiki_db,
      user_id
)
SELECT
  interaction_type,
  wiki_db,
  user_id,
  num_events,
  pct_events
FROM (
    SELECT
      wiki_db,
      user_id,
      interaction_type,
      num_events,
      num_events / (SUM(num_events) OVER (PARTITION BY wiki_db, interaction_type)) AS pct_events
    FROM actions_per_user
    UNION ALL
    SELECT
      wiki_db,
      user_id,
      '3-edit' AS interaction_type,
      num_events,
      num_events / (SUM(num_events) OVER (PARTITION BY wiki_db)) AS pct_events
    FROM edits_per_user
) a
WHERE
  pct_events >= 0.02
ORDER BY
  interaction_type,
  pct_events DESC
LIMIT 500
"""

if print_for_hive:
    print(re.sub(' +', ' ', re.sub('\n', ' ', query)).strip())
else:
    print(query)

if do_execute:
    result = spark.sql(query)
    result.show(500, False)
    
# Output:
# +----------------+-------------+----------+--------------------+
# |interaction_type|user_id      |num_events|pct_events          |
# +----------------+-------------+----------+--------------------+
# |2-click         |<  deleted  >|1452      |0.03243460584805772 |
# |2-click         |<  deleted  >|1051      |0.023477114839055555|
# |3-edit          |<  deleted  >|1320      |0.04619584237418632 |
# |3-edit          |<  deleted  >|573       |0.02005319521243088 |
# +----------------+-------------+----------+--------------------+
